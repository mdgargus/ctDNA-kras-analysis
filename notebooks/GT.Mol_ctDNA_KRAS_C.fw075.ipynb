# %% [markdown]
# # 1. Introduction
#
# This notebook is for targeted variant analysis of KRAS in circulating tumor DNA (ctDNA) from a single patient (C_fw075). The raw data is from the NCBI BioProject PRJNA714799 related to the following publication:
#
# O’Dea et al. Circulating tumor DNA sequencing in colorectal cancer patients treated with first-line chemotherapy with anti-EGFR. Scientific        Reports. 2021
#
#
# You will find sections in the notebook for:
#
# - processing raw paired-end ctDNA reads,
# - align them to the human reference genome GRCh38
# - perform variant calling with VarScan in the KRAS locus,
# - annotate and interpret any the mutations in the KRAS region for clinically relevant alterations,
# - briefly consider whether any new KRAS alterations emerge at follow-up.

# %% [markdown]
# # 2. Environment
#
# All analyses were run on WSL2 UBUNTU on a personal (no organization affiliation) Windows 11 machine using a Conda environment named `ngs`. The environment contains common NGS tools:
#
# `fastqc` – QC tool
# `bowtie2` – aligner
# `samtools` – BAM handling and mpileup generation
# `bcftools` – VCF utilities
# `varscan` – variant calling
# `snpEff` – variant annotation
#
# Python 3.11.14 (Jupyter in VSC) is used for:
#
# light bookkeeping (paths, listing files),
# parsing annotated VCFs and summarizing KRAS variants.
# Text editing and summarizing.

# %%
#python imports

import pandas as pd
import os, glob
from pathlib import Path

# %%
# Define project root and all key subdirectories in one place

project_root = Path("/home/mgpersonal/ctdna_kras_project").resolve()

data_dir   = project_root / "data"
fastq_dir  = data_dir / "fastq"
ref_dir    = data_dir / "ref"
results_dir = project_root / "results"
bam_dir     = results_dir / "bam"
vcf_dir    = results_dir/ "vcf"
qc_dir  = results_dir/ "qc"
out_dir="${project_root}/results/summary"

# Existing Reference files (Moved a GRCh38 .fa and bowtie2 reference from my system to these directories)
ref_fasta  = ref_dir / "Homo_sapiens.GRCh38.dna.primary_assembly.fa"
ref_prefix  = ref_dir / "GRCh38_primary"  # Bowtie2 index prefix

# Create directory structure if it doesn't already exist
for d in [data_dir, fastq_dir, ref_dir, results_dir, bam_dir, vcf_dir]:
    d.mkdir(parents=True, exist_ok=True)

#Let's make sure everything is prese
print("project root:", project_root)
print("fastq_dir   :", fastq_dir)
print("ref_dir     :", ref_dir)
print("bam_dir     :", bam_dir)
print("vcf_dir     :", vcf_dir)
print("Reference fasta:", ref_fasta)
print("Bowtie2 prefix:", ref_prefix)
# Out:
# project root: /home/mgpersonal/ctdna_kras_project
# fastq_dir   : /home/mgpersonal/ctdna_kras_project/data/fastq
# ref_dir     : /home/mgpersonal/ctdna_kras_project/data/ref
# bam_dir     : /home/mgpersonal/ctdna_kras_project/results/bam
# vcf_dir     : /home/mgpersonal/ctdna_kras_project/results/vcf
# Reference fasta: /home/mgpersonal/ctdna_kras_project/data/ref/Homo_sapiens.GRCh38.dna.primary_assembly.fa
# Bowtie2 prefix: /home/mgpersonal/ctdna_kras_project/data/ref/GRCh38_primary

# %% [markdown]
# # 3. Data Acquisition
#
# I selected C_fw075 after reviewing the runinfo.csv in the repository because it had 1 baseline and 1 follow-up cell free dna sample.
#
# Our pre-treatment sample is `SRR13973824` → sample label `C_fw075_baseline`
# Our post or follow-up treatment sample `SRR13973825` → sample label `C_fw075_followup`
#
# The raw data were obtained from the NCBI SRA project associated with the paper.
# In practice, I pulled the data using `prefetch` and `fasterq-dump` (only run once on my machine). An example of the commands is:

# %%
###First we need to inspect runinfo on NCBI repository to select a subject C_fw pre and post sample(follow-up)
#I just downloaded this file when I was browsing and moved the .csv into the sra directory.

runinfo_path = "/home/mgpersonal/ctdna_kras_project/data/sra/PRJNA714799_runinfo.csv"
runinfo = pd.read_csv(runinfo_path)


runinfo.head()

###Had to manually inspect/confirm the SampleName column has the information we want.
# Out:
#            Run          ReleaseDate             LoadDate    spots      bases  \
# 0  SRR13974039  2022-04-18 00:00:24  2021-03-16 08:45:24  2132268  615326977
# 1  SRR13974041  2022-04-18 00:00:24  2021-03-16 08:45:29  2704436  789609381
# 2  SRR13974040  2022-04-18 00:00:24  2021-03-16 08:45:31  2263227  659576113
# 3  SRR13974043  2022-04-18 00:00:24  2021-03-16 08:47:07   944806  265589338
# 4  SRR13974042  2022-04-18 00:00:24  2021-03-16 08:46:13  1374004  389796958
#
#    spots_with_mates  avgLength  size_MB      AssemblyName  \
# 0           2053223        288      350  GCA_000001405.13
# 1           2632994        291      420  GCA_000001405.13
# 2           2218251        291      354  GCA_000001405.13
# 3            900493        281      141  GCA_000001405.13
# 4           1360349        283      182  GCA_000001405.13
#
#                                        download_path  ... Affection_Status  \
# 0  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...              NaN
# 1  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...              NaN
# 2  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...              NaN
# 3  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...              NaN
# 4  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...              NaN
#
#   Analyte_Type Histological_Type Body_Site                 CenterName  \
# 0          NaN               NaN       NaN  SEOUL NATIONAL UNIVERSITY
# 1          NaN               NaN       NaN  SEOUL NATIONAL UNIVERSITY
# 2          NaN               NaN       NaN  SEOUL NATIONAL UNIVERSITY
# 3          NaN               NaN       NaN  SEOUL NATIONAL UNIVERSITY
# 4          NaN               NaN       NaN  SEOUL NATIONAL UNIVERSITY
#
#    Submission  dbgap_study_accession  Consent  \
# 0  SRA1206760                    NaN   public
# 1  SRA1206760                    NaN   public
# 2  SRA1206760                    NaN   public
# 3  SRA1206760                    NaN   public
# 4  SRA1206760                    NaN   public
#
#                             RunHash                          ReadHash
# 0  25A5EE99E44E4FBC0D6B95BE1221A156  5A979126CE22F541C18C1B3DB7394495
# 1  099ADF641FDB3EC474D711584108DBB1  86C1109112E35E3F10C96AFAB8216EC2
# 2  C85AA55C37FB24B12E19C3B70DC7EC67  CBF81247DE6651D5F9633ACB7E61A8A4
# 3  B07E7B03747F8B6788FECE06D2052AB7  01C130C3118CF67695B55B2D77782834
# 4  8BE2BA608B12D72AEFFB1939015AFFF7  23C18760023C61F4C910D0CDA575CE91
#
# [5 rows x 47 columns]

# %%
###Identify the samples and the Run ID SRR
samples = runinfo["SampleName"].isin(["C_fw075", "C_fw075-2"])
ctdna = runinfo.loc[samples, ["Run", "SampleName"]]
ctdna
# Out:
#              Run SampleName
# 208  SRR13973824    C_fw075
# 209  SRR13973825  C_fw075-2

# %%
# %%bash
# set -euo pipefail
#
# project_root="/home/mgpersonal/ctdna_kras_project"
# fastq_dir="${project_root}/data/fastq"
# tmp_dir="${project_root}/data/sra_tmp"
#
# mkdir -p "${fastq_dir}" "${tmp_dir}"
#
# for srr in SRR13973824 SRR13973825; do
#   fasterq-dump \
#     --split-3 \
#     --temp "${tmp_dir}" \
#     -O "${fastq_dir}" \
#     "${srr}"
# done
# Out:
# spots read      : 4,998,783
# reads read      : 9,997,566
# reads written   : 9,905,463
# spots read      : 5,508,730
# reads read      : 11,017,460
# reads written   : 10,946,198

# %%
# %%bash
# set -euo pipefail
#
# #need for shell
# project_root="/home/mgpersonal/ctdna_kras_project"
# fastq_dir="${project_root}/data/fastq"
#
# for srr in SRR13973824 SRR13973825; do
#   wc -l "${fastq_dir}/${srr}_1.fastq" "${fastq_dir}/${srr}_2.fastq"
# done
#
# ##I was having an issue with different reads coming out of a 2 split so I made it a 3 split in the previous cell and now R1 and R2 work for pre and follow-up sample
# #this just verifies R1 and R2 are the same for bowtie2.
# Out:
#   19626720 /home/mgpersonal/ctdna_kras_project/data/fastq/SRR13973824_1.fastq
#   19626720 /home/mgpersonal/ctdna_kras_project/data/fastq/SRR13973824_2.fastq
#   39253440 total
#   21749872 /home/mgpersonal/ctdna_kras_project/data/fastq/SRR13973825_1.fastq
#   21749872 /home/mgpersonal/ctdna_kras_project/data/fastq/SRR13973825_2.fastq
#   43499744 total

# %% [markdown]
# # 4. QC - FASTQC assessment
#
# Sequenced quality was assessed for the C_fw075 subject's pre and follow-up forward and reverse fastq files. Read quality, GC content, and adapter content all appeared good. It didn't look like there was any striking adapter or issues with falloff at the tails.
#
# I decided not to perform any trimming because of the decent quality (> 30 fred). I will certainly reassess if I see anything concerning downstream. It looks like the authors of the paper do have a "filtered" file in their methods, but I couldn't find the exact method and I did not want to get too fixed on this for the puprose and scope of the assignment.

# %%
###Check fastqs (not included) to make sure we have all pairs.
##We can just keep the singletons in the .fastq

fastqs = sorted(glob.glob(os.path.join(fastq_dir, "*.fastq*")))
fastqs
# Out:
# ['/home/mgpersonal/ctdna_kras_project/data/fastq/SRR13973824.fastq',
#  '/home/mgpersonal/ctdna_kras_project/data/fastq/SRR13973824_1.fastq',
#  '/home/mgpersonal/ctdna_kras_project/data/fastq/SRR13973824_2.fastq',
#  '/home/mgpersonal/ctdna_kras_project/data/fastq/SRR13973825.fastq',
#  '/home/mgpersonal/ctdna_kras_project/data/fastq/SRR13973825_1.fastq',
#  '/home/mgpersonal/ctdna_kras_project/data/fastq/SRR13973825_2.fastq']

# %%
###Running fASTQC for Read Quality Assessment
#Asess raw read quality for the baseline and follow-up ctDNA fastq files

# Find all FASTQ files in fastq_dir
fastqs = sorted(glob.glob(os.path.join(fastq_dir, "*.fastq")))

for f in fastqs:
    print("  -", os.path.basename(f))

# Need to add a space for FASTQC command to work
fastqs_str = " ".join(fastqs)

# Run FastQC
# !fastqc -o {qc_dir} {fastqs_str}
# Out:
#   - SRR13973824.fastq
#   - SRR13973824_1.fastq
#   - SRR13973824_2.fastq
#   - SRR13973825.fastq
#   - SRR13973825_1.fastq
#   - SRR13973825_2.fastq
# null
# null
# Started analysis of SRR13973824.fastq
# null
# null
# null
# null
# Approx 5% complete for SRR13973824.fastq
# Approx 10% complete for SRR13973824.fastq
# Approx 15% complete for SRR13973824.fastq
# Approx 20% complete for SRR13973824.fastq
# Approx 25% complete for SRR13973824.fastq
# Approx 30% complete for SRR13973824.fastq
# Approx 35% complete for SRR13973824.fastq
# Approx 40% complete for SRR13973824.fastq
# Approx 45% complete for SRR13973824.fastq
# Approx 50% complete for SRR13973824.fastq
# Approx 55% complete for SRR13973824.fastq
# Approx 60% complete for SRR13973824.fastq
# Approx 65% complete for SRR13973824.fastq
# Approx 70% complete for SRR13973824.fastq
# Approx 75% complete for SRR13973824.fastq
# Approx 80% complete for SRR13973824.fastq
# Approx 85% complete for SRR13973824.fastq
# Approx 90% complete for SRR13973824.fastq
# Approx 95% complete for SRR13973824.fastq
# Analysis complete for SRR13973824.fastq
# Started analysis of SRR13973824_1.fastq
# Approx 5% complete for SRR13973824_1.fastq
# Approx 10% complete for SRR13973824_1.fastq
# Approx 15% complete for SRR13973824_1.fastq
# Approx 20% complete for SRR13973824_1.fastq
# Approx 25% complete for SRR13973824_1.fastq
# Approx 30% complete for SRR13973824_1.fastq
# Approx 35% complete for SRR13973824_1.fastq
# Approx 40% complete for SRR13973824_1.fastq
# Approx 45% complete for SRR13973824_1.fastq
# Approx 50% complete for SRR13973824_1.fastq
# Approx 55% complete for SRR13973824_1.fastq
# Approx 60% complete for SRR13973824_1.fastq
# Approx 65% complete for SRR13973824_1.fastq
# Approx 70% complete for SRR13973824_1.fastq
# Approx 75% complete for SRR13973824_1.fastq
# Approx 80% complete for SRR13973824_1.fastq
# Approx 85% complete for SRR13973824_1.fastq
# Approx 90% complete for SRR13973824_1.fastq
# Approx 95% complete for SRR13973824_1.fastq
# Analysis complete for SRR13973824_1.fastq
# Started analysis of SRR13973824_2.fastq
# Approx 5% complete for SRR13973824_2.fastq
# Approx 10% complete for SRR13973824_2.fastq
# Approx 15% complete for SRR13973824_2.fastq
# Approx 20% complete for SRR13973824_2.fastq
# Approx 25% complete for SRR13973824_2.fastq
# Approx 30% complete for SRR13973824_2.fastq
# Approx 35% complete for SRR13973824_2.fastq
# Approx 40% complete for SRR13973824_2.fastq
# Approx 45% complete for SRR13973824_2.fastq
# Approx 50% complete for SRR13973824_2.fastq
# Approx 55% complete for SRR13973824_2.fastq
# Approx 60% complete for SRR13973824_2.fastq
# Approx 65% complete for SRR13973824_2.fastq
# Approx 70% complete for SRR13973824_2.fastq
# Approx 75% complete for SRR13973824_2.fastq
# Approx 80% complete for SRR13973824_2.fastq
# Approx 85% complete for SRR13973824_2.fastq
# Approx 90% complete for SRR13973824_2.fastq
# Approx 95% complete for SRR13973824_2.fastq
# Analysis complete for SRR13973824_2.fastq
# Started analysis of SRR13973825.fastq
# Approx 5% complete for SRR13973825.fastq
# Approx 10% complete for SRR13973825.fastq
# Approx 15% complete for SRR13973825.fastq
# Approx 20% complete for SRR13973825.fastq
# Approx 25% complete for SRR13973825.fastq
# Approx 30% complete for SRR13973825.fastq
# Approx 35% complete for SRR13973825.fastq
# Approx 40% complete for SRR13973825.fastq
# Approx 45% complete for SRR13973825.fastq
# Approx 50% complete for SRR13973825.fastq
# Approx 55% complete for SRR13973825.fastq
# Approx 60% complete for SRR13973825.fastq
# Approx 65% complete for SRR13973825.fastq
# Approx 70% complete for SRR13973825.fastq
# Approx 75% complete for SRR13973825.fastq
# Approx 80% complete for SRR13973825.fastq
# Approx 85% complete for SRR13973825.fastq
# Approx 90% complete for SRR13973825.fastq
# Approx 95% complete for SRR13973825.fastq
# Analysis complete for SRR13973825.fastq
# Started analysis of SRR13973825_1.fastq
# Approx 5% complete for SRR13973825_1.fastq
# Approx 10% complete for SRR13973825_1.fastq
# Approx 15% complete for SRR13973825_1.fastq
# Approx 20% complete for SRR13973825_1.fastq
# Approx 25% complete for SRR13973825_1.fastq
# Approx 30% complete for SRR13973825_1.fastq
# Approx 35% complete for SRR13973825_1.fastq
# Approx 40% complete for SRR13973825_1.fastq
# Approx 45% complete for SRR13973825_1.fastq
# Approx 50% complete for SRR13973825_1.fastq
# Approx 55% complete for SRR13973825_1.fastq
# Approx 60% complete for SRR13973825_1.fastq
# Approx 65% complete for SRR13973825_1.fastq
# Approx 70% complete for SRR13973825_1.fastq
# Approx 75% complete for SRR13973825_1.fastq
# Approx 80% complete for SRR13973825_1.fastq
# Approx 85% complete for SRR13973825_1.fastq
# Approx 90% complete for SRR13973825_1.fastq
# Approx 95% complete for SRR13973825_1.fastq
# Analysis complete for SRR13973825_1.fastq
# Started analysis of SRR13973825_2.fastq
# Approx 5% complete for SRR13973825_2.fastq
# Approx 10% complete for SRR13973825_2.fastq
# Approx 15% complete for SRR13973825_2.fastq
# Approx 20% complete for SRR13973825_2.fastq
# Approx 25% complete for SRR13973825_2.fastq
# Approx 30% complete for SRR13973825_2.fastq
# Approx 35% complete for SRR13973825_2.fastq
# Approx 40% complete for SRR13973825_2.fastq
# Approx 45% complete for SRR13973825_2.fastq
# Approx 50% complete for SRR13973825_2.fastq
# Approx 55% complete for SRR13973825_2.fastq
# Approx 60% complete for SRR13973825_2.fastq
# Approx 65% complete for SRR13973825_2.fastq
# Approx 70% complete for SRR13973825_2.fastq
# Approx 75% complete for SRR13973825_2.fastq
# Approx 80% complete for SRR13973825_2.fastq
# Approx 85% complete for SRR13973825_2.fastq
# Approx 90% complete for SRR13973825_2.fastq
# Approx 95% complete for SRR13973825_2.fastq
# Analysis complete for SRR13973825_2.fastq

# %% [markdown]
# 5. Analysis
#
# Paired-reads of the baseline and follow-up samples are aligned to the GRCh38 reference genome using bowtie2. The sorted.bams are indexed and we perform variant calling with VarScan mpileup2cn restricted to the KRAS region chr12:25245300–25245400. The VCF parameters were very flexible to try to detect any small fraction mutation that might appear, or even a de-novo alteration. The VCF files for baseline and follow-up samples were annotated with SnipEff (VEP and ClinVar would be nice, but they were not working well in my environment. COSMIC is unfortanately not available for personal non-affiliated use) There was evidence of the clinically meaningful mutation KRAS G12D present in the baseline sample but not the follow-up sample suggesting the metastatic CRC is responding to cetuximab treatment.
#
# Below are the key finding and commentary:
#
# 1. Baseline Sample: Clear Detection of Oncogenic KRAS G12D
#
# In the baseline sample (C_fw075_baseline), we observe a well-supported KRAS G12D mutation (cDNA change 35G>A; Protein change Gly12Asp):
#
# Position: chr12:25245350
# Reference / Alt: C>T (GRCh38)
# Depth: ~1,300× total coverage
# ALT allele count: ~110 reads
# VAF: ~8.3%
# Annotation: missense_variant, impact: MODERATE
#
# KRAS G12D is a well-known hotspot mutation and a common driver of several cancers including CRC. In the baseline sample it is present at  about 8% VAF. Since this is from circulating DNA it likely would have a smaller VAF. Importantly, the mutation is supported by high depth and can be considered a robust call.
#
# 2. Follow-up Sample: Absence of KRAS G12D and No High-Confidence Driver Mutations
#
# In the follow-up sample (C_fw075_followup), no G12D mutation is detected, even at low allele frequencies. Instead, the only KRAS-related variant observed is:
#
# Position: chr12:25250747
# Change: G>A
# Effect: splice_region_variant & intron_variant
# Depth: 46×
# ALT allele count: 2
# VAF: 4%
# Annotation impact: LOW
#
# Even though this variant has an LOW annotation impact from SnpEFF, there is not too much known about it. It is also at a very low depth and VAF. For these 2 reasons it can be considered a weak call, if not background. The absence of the KRAS G12D alteration is likely due to cetuximab treatment response. It can be a bit reassuring to the patient that the levels of that oncogenic driver are not detectable post treatment.
#
# It is also good to see no new robust KRAS alteration appear like G12C, A, R, etc. even though this is not the usual resistance mechanism to cetuximab.

# %%
###Review the FASTQC .hmtl files
#It looks like the sequences are pretty good quality (>30) in all the files. Sure the adapters and tails fall off a bit, but since I am less familiar with this exact targetted sequencing, I am going to avoid trimming unless something looks concerning down the line.
qc_dir = "/home/mgpersonal/ctdna_kras_project/results/qc"
sorted(glob.glob(os.path.join(qc_dir, "*fastqc.html")))
# Out:
# ['/home/mgpersonal/ctdna_kras_project/results/qc/SRR13973824_1_fastqc.html',
#  '/home/mgpersonal/ctdna_kras_project/results/qc/SRR13973824_2_fastqc.html',
#  '/home/mgpersonal/ctdna_kras_project/results/qc/SRR13973824_fastqc.html',
#  '/home/mgpersonal/ctdna_kras_project/results/qc/SRR13973825_1_fastqc.html',
#  '/home/mgpersonal/ctdna_kras_project/results/qc/SRR13973825_2_fastqc.html',
#  '/home/mgpersonal/ctdna_kras_project/results/qc/SRR13973825_fastqc.html']

# %%
# %%bash
# set -euo pipefail
#
# #need to def these again for this bash shell
# project_root="/home/mgpersonal/ctdna_kras_project"
# fastq_dir="${project_root}/data/fastq"
# ref_dir="${project_root}/data/ref"
# bam_dir="${project_root}/results/bam"
#
# ref_prefix="${ref_dir}/GRCh38_primary"
#
#
# sra_id="SRR13973824"
# label="C_fw075_baseline"
#
# R1="${fastq_dir}/${sra_id}_1.fastq"
# R2="${fastq_dir}/${sra_id}_2.fastq"
#
# echo "Aligning ${sra_id} (${label})..."
# bowtie2 -x "${ref_prefix}" \
#   -1 "${R1}" -2 "${R2}" \
#   -p 8 \
#   2> "${bam_dir}/${label}.bowtie2.log" \
# | samtools sort -o "${bam_dir}/${label}.sorted.bam"
#
# #.sorted.bam created for pre sample
# Out:
# Aligning SRR13973824 (C_fw075_baseline)...
# ERROR! Session/line number was not unique in database. History logging moved to new session 17
# [bam_sort_core] merging from 4 files and 1 in-memory blocks...

# %%
# %%bash
# set -euo pipefail
#
# #need to def these again for this bash shell
# project_root="/home/mgpersonal/ctdna_kras_project"
# fastq_dir="${project_root}/data/fastq"
# ref_dir="${project_root}/data/ref"
# bam_dir="${project_root}/results/bam"
#
# ref_prefix="${ref_dir}/GRCh38_primary"
#
# #change these for follow-up
# sra_id="SRR13973825"
# label="C_fw075_followup"
#
# R1="${fastq_dir}/${sra_id}_1.fastq"
# R2="${fastq_dir}/${sra_id}_2.fastq"
#
# echo "Aligning ${sra_id} (${label})..."
# bowtie2 -x "${ref_prefix}" \
#   -1 "${R1}" -2 "${R2}" \
#   -p 8 \
#   2> "${bam_dir}/${label}.bowtie2.log" \
# | samtools sort -o "${bam_dir}/${label}.sorted.bam"
#
# #.sorted.bam created for follow-up sample
# Out:
# Aligning SRR13973825 (C_fw075_followup)...
# [bam_sort_core] merging from 5 files and 1 in-memory blocks...

# %%
# %%bash
# set -euo pipefail
#
# bam_dir="/home/mgpersonal/ctdna_kras_project/results/bam"
# cd "${bam_dir}"
#
# for bam in *.sorted.bam; do
#     echo "Indexing $bam"
#     samtools index "$bam"
# done
#
# echo "Done."
#
#
# #we are just indexing our .sorted.bams here
# Out:
# Indexing C_fw075_baseline.sorted.bam
# Indexing C_fw075_followup.sorted.bam
# Done.

# %%
# %%bash
# set -euo pipefail
#
# project_root="/home/mgpersonal/ctdna_kras_project"
# ref_dir="${project_root}/data/ref"
# bam_dir="${project_root}/results/bam"
# vcf_dir="${project_root}/results/vcf"
#
# ref_fasta="${ref_dir}/Homo_sapiens.GRCh38.dna.primary_assembly.fa"
# # looked up GRCh38 KRAS coordinates on Ensembl 12: 25,205,246-25,250,936 reverse strand. Padded the region slightly.
# region="12:25204000-25253000"
#
# # Let's confirm our sorted sorted.bams
# echo "BAMs:"
# ls -lh "${bam_dir}"/*.sorted.bam || true
#
# # loop over pre and follow-up sample creating mpileup straight to VCF file of KRAS region
# for label in C_fw075_baseline C_fw075_followup; do
#     bam="${bam_dir}/${label}.sorted.bam"
#     mpileup="${vcf_dir}/${label}.kras.mpileup"
#     vcf="${vcf_dir}/${label}.kras.varscan.vcf"
#
#     echo
#     echo "mpileup + VarScan for ${label}"
#     echo "  BAM: ${bam}"
#     echo "  Region: ${region}"
#
#     # mpileup restricted to KRAS region
#     samtools mpileup -f "${ref_fasta}" -r "${region}" "${bam}" > "${mpileup}"
#
#     # VarScan consensus
#     #
#     varscan mpileup2cns "${mpileup}" \
#         --min-coverage 10 \
#         --min-avg-qual 25 \
#         --min-var-freq 0.01 \
#         --p-value 0.99 \
#         --output-vcf 1 > "${vcf}"
#
#     echo "  vcf created: ${vcf}"
# done
#
# echo
# echo "Done."
# Out:
# BAMs:
# -rw-r--r-- 1 mgpersonal mgpersonal 846M Nov 15 14:38 /home/mgpersonal/ctdna_kras_project/results/bam/C_fw075_baseline.sorted.bam
# -rw-r--r-- 1 mgpersonal mgpersonal 900M Nov 15 14:51 /home/mgpersonal/ctdna_kras_project/results/bam/C_fw075_followup.sorted.bam
#
# mpileup + VarScan for C_fw075_baseline
#   BAM: /home/mgpersonal/ctdna_kras_project/results/bam/C_fw075_baseline.sorted.bam
#   Region: 12:25204000-25253000
# [mpileup] 1 samples in 1 input files
# /home/mgpersonal/miniconda3/envs/ngs/bin/varscan: line 6: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8): No such file or directory
# Min coverage:	10
# Min reads2:	2
# Min var freq:	0.01
# Min avg qual:	25
# P-value thresh:	0.99
# Reading input from /home/mgpersonal/ctdna_kras_project/results/vcf/C_fw075_baseline.kras.mpileup
# 9037 bases in pileup file
# 28 variant positions (21 SNP, 7 indel)
# 5 were failed by the strand-filter
# 28 variant positions reported (21 SNP, 7 indel)
#   vcf created: /home/mgpersonal/ctdna_kras_project/results/vcf/C_fw075_baseline.kras.varscan.vcf
#
# mpileup + VarScan for C_fw075_followup
#   BAM: /home/mgpersonal/ctdna_kras_project/results/bam/C_fw075_followup.sorted.bam
#   Region: 12:25204000-25253000
# [mpileup] 1 samples in 1 input files
# /home/mgpersonal/miniconda3/envs/ngs/bin/varscan: line 6: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8): No such file or directory
# Min coverage:	10
# Min reads2:	2
# Min var freq:	0.01
# Min avg qual:	25
# P-value thresh:	0.99
# Reading input from /home/mgpersonal/ctdna_kras_project/results/vcf/C_fw075_followup.kras.mpileup
# 8233 bases in pileup file
# 20 variant positions (13 SNP, 7 indel)
# 2 were failed by the strand-filter
# 20 variant positions reported (13 SNP, 7 indel)
#   vcf created: /home/mgpersonal/ctdna_kras_project/results/vcf/C_fw075_followup.kras.varscan.vcf
#
# Done.

# %%
# %%bash
# set -euo pipefail
# cd ~/ctdna_kras_project/results/vcf
#
# # baseline
# snpEff -Xmx4g -v GRCh38.99 \
#   C_fw075_baseline.kras.varscan.vcf \
#   > C_fw075_baseline.kras.ann.vcf
#
# # follow-up
# snpEff -Xmx4g -v GRCh38.99 \
#   C_fw075_followup.kras.varscan.vcf \
#   > C_fw075_followup.kras.ann.vcf
# Out:
# 00:00:00 SnpEff version SnpEff 5.3a (build 2025-09-02 10:24), by Pablo Cingolani
# 00:00:00 Command: 'ann'
# 00:00:00 Reading configuration file 'snpEff.config'. Genome: 'GRCh38.99'
# 00:00:00 Looking for config file: '/home/mgpersonal/ctdna_kras_project/results/vcf/snpEff.config'
# 00:00:00 Reading config file: /home/mgpersonal/miniconda3/envs/ngs/share/snpeff-5.3.0a-1/snpEff.config
# 00:00:00 done
# 00:00:00 Reading database for genome version 'GRCh38.99' from file '/home/mgpersonal/miniconda3/envs/ngs/share/snpeff-5.3.0a-1/./data/GRCh38.99/snpEffectPredictor.bin' (this might take a while)
# 00:00:13 done
# 00:00:13 Loading Motifs and PWMs
# 00:00:13 Building interval forest
# 00:00:17 done.
# 00:00:17 Genome stats :
# #-----------------------------------------------
# # Genome name                : 'Homo_sapiens'
# # Genome version             : 'GRCh38.99'
# # Genome ID                  : 'GRCh38.99[0]'
# # Has protein coding info    : true
# # Has Tr. Support Level info : true
# # Genes                      : 60676
# # Protein coding genes       : 20135
# #-----------------------------------------------
# # Transcripts                : 227818
# # Avg. transcripts per gene  : 3.75
# # TSL transcripts            : 169199
# #-----------------------------------------------
# # Checked transcripts        :
# #               AA sequences : 100576 ( 119.03% )
# #              DNA sequences : 172288 ( 75.63% )
# #-----------------------------------------------
# # Protein coding transcripts : 84494
# #              Length errors :  13469 ( 15.94% )
# #  STOP codons in CDS errors :     34 ( 0.04% )
# #         START codon errors :   8149 ( 9.64% )
# #        STOP codon warnings :   7264 ( 8.60% )
# #              UTR sequences :  81637 ( 35.83% )
# #               Total Errors :  20119 ( 23.81% )
# #-----------------------------------------------
# # Cds                        : 764354
# # Exons                      : 1376499
# # Exons with sequence        : 1376499
# # Exons without sequence     : 0
# # Avg. exons per transcript  : 6.04
# # WARNING!                   : Mitochondrion chromosome 'MT' does not have a mitochondrion codon table (codon table = 'Standard'). You should update the config file.
# #-----------------------------------------------
# # Number of chromosomes      : 639
# # Chromosomes                : Format 'chromo_name size codon_table'
# #		'HSCHR1_2_CTG3'	248975002	Standard
# #		'HSCHR1_1_CTG31'	248973653	Standard
# #		'HSCHR1_2_CTG31'	248971826	Standard
# #		'HSCHR1_1_CTG3'	248968406	Standard
# #		'HSCHR1_3_CTG31'	248967909	Standard
# #		'HSCHR1_9_CTG3'	248965380	Standard
# #		'HSCHR1_4_CTG3'	248963886	Standard
# #		'HSCHR1_2_CTG32_1'	248962488	Standard
# #		'HSCHR1_8_CTG3'	248962151	Standard
# #		'HSCHR1_3_CTG3'	248961700	Standard
# #		'HSCHR1_1_CTG11'	248961539	Standard
# #		'HSCHR1_3_CTG32_1'	248960761	Standard
# #		'HSCHR1_5_CTG32_1'	248960213	Standard
# #		'HSCHR1_1_CTG32_1'	248960143	Standard
# #		'HG1832_PATCH'	248959779	Standard
# #		'HG2095_PATCH'	248959131	Standard
# #		'HSCHR1_ALT2_1_CTG32_1'	248958866	Standard
# #		'HSCHR1_4_CTG32_1'	248958766	Standard
# #		'HG2104_PATCH'	248958259	Standard
# #		'HG986_PATCH'	248956639	Standard
# #		'1'	248956422	Standard
# #		'HG2058_PATCH'	248956422	Standard
# #		'HSCHR1_6_CTG3'	248955842	Standard
# #		'HG460_PATCH'	248955838	Standard
# #		'HSCHR1_4_CTG31'	248955631	Standard
# #		'HG2002_PATCH'	248942227	Standard
# #		'HG1342_HG2282_PATCH'	248929249	Standard
# #		'HSCHR1_5_CTG3'	248926662	Standard
# #		'HG2290_PATCH'	242235269	Standard
# #		'HSCHR2_2_CTG7'	242223512	Standard
# #		'HSCHR2_1_CTG7_2'	242210518	Standard
# #		'HSCHR2_7_CTG7_2'	242202531	Standard
# #		'HSCHR2_5_CTG7_2'	242199685	Standard
# #		'HSCHR2_8_CTG7_2'	242199670	Standard
# #		'HSCHR2_2_CTG7_2'	242199609	Standard
# #		'HSCHR2_1_CTG5'	242199562	Standard
# #		'HSCHR2_1_CTG15'	242198904	Standard
# #		'HSCHR2_2_CTG15'	242198544	Standard
# #		'HSCHR2_2_CTG1'	242198346	Standard
# #		'HSCHR2_6_CTG7_2'	242198149	Standard
# #		'HSCHR2_4_CTG7_2'	242196589	Standard
# #		'HSCHR2_3_CTG1'	242195626	Standard
# #		'HG1384_PATCH'	242195459	Standard
# #		'HSCHR2_1_CTG1'	242194896	Standard
# #		'HSCHR2_3_CTG7_2'	242194557	Standard
# #		'HSCHR2_3_CTG15'	242194292	Standard
# #		'HG721_PATCH'	242194216	Standard
# #		'HSCHR2_1_CTG7'	242193540	Standard
# #		'HG2233_PATCH'	242193535	Standard
# #		'2'	242193529	Standard
# #		'HG2232_PATCH'	242193529	Standard
# #		'HSCHR2_4_CTG1'	242191076	Standard
# #		'HSCHR3_4_CTG1'	198310749	Standard
# #		'HSCHR3_1_CTG2_1'	198306097	Standard
# #		'HSCHR3_5_CTG1'	198305844	Standard
# #		'HSCHR3_6_CTG2_1'	198305007	Standard
# #		'HSCHR3_1_CTG3'	198302882	Standard
# #		'HSCHR3_9_CTG2_1'	198302489	Standard
# #		'HSCHR3_8_CTG2_1'	198302280	Standard
# #		'HSCHR3_4_CTG2_1'	198301383	Standard
# #		'HSCHR3_7_CTG2_1'	198301024	Standard
# #		'HSCHR3_5_CTG2_1'	198300594	Standard
# #		'HSCHR3_3_CTG2_1'	198300421	Standard
# #		'HSCHR3_3_CTG1'	198300110	Standard
# #		'HG2133_PATCH'	198299611	Standard
# #		'HSCHR3_2_CTG2_1'	198298736	Standard
# #		'HSCHR3_1_CTG1'	198297480	Standard
# #		'HSCHR3_2_CTG3'	198296961	Standard
# #		'HSCHR3_4_CTG3'	198296867	Standard
# #		'HG2022_PATCH'	198295941	Standard
# #		'HSCHR3_8_CTG3'	198295934	Standard
# #		'HG126_PATCH'	198295908	Standard
# #		'HG2235_PATCH'	198295655	Standard
# #		'3'	198295559	Standard
# #		'HG2066_PATCH'	198295555	Standard
# #		'HG2236_PATCH'	198295537	Standard
# #		'HSCHR3_6_CTG3'	198294921	Standard
# #		'HSCHR3_7_CTG3'	198294497	Standard
# #		'HSCHR3_5_CTG3'	198293785	Standard
# #		'HSCHR3_3_CTG3'	198293223	Standard
# #		'HSCHR3_9_CTG3'	198291952	Standard
# #		'HG2237_PATCH'	198290329	Standard
# #		'HG2525_PATCH'	190293418	Standard
# #		'HSCHR4_11_CTG12'	190233769	Standard
# #		'HSCHR4_1_CTG12'	190227204	Standard
# #		'HSCHR4_7_CTG12'	190225141	Standard
# #		'HSCHR4_1_CTG6'	190224838	Standard
# #		'HSCHR4_1_CTG4'	190221757	Standard
# #		'HSCHR4_12_CTG12'	190221648	Standard
# #		'HSCHR4_4_CTG12'	190220704	Standard
# #		'HSCHR4_5_CTG12'	190219562	Standard
# #		'HSCHR4_9_CTG12'	190219005	Standard
# #		'HSCHR4_1_CTG8_1'	190218838	Standard
# #		'HSCHR4_6_CTG12'	190218533	Standard
# #		'HSCHR4_8_CTG12'	190218480	Standard
# #		'HSCHR4_3_CTG12'	190218028	Standard
# #		'HSCHR4_2_CTG4'	190217898	Standard
# #		'4'	190214555	Standard
# #		'HG699_PATCH'	190211220	Standard
# #		'HG1296_PATCH'	190208697	Standard
# #		'HSCHR4_2_CTG12'	190206797	Standard
# #		'HG1299_PATCH'	190201596	Standard
# #		'HG1298_PATCH'	190196285	Standard
# #		'HG705_PATCH'	190172551	Standard
# #		'HG2023_PATCH'	190147504	Standard
# #		'HSCHR4_1_CTG9'	190096932	Standard
# #		'HSCHR5_8_CTG1'	181668817	Standard
# #		'HSCHR5_1_CTG1'	181558402	Standard
# #		'HSCHR5_3_CTG1_1'	181554865	Standard
# #		'HSCHR5_2_CTG1'	181547139	Standard
# #		'HSCHR5_4_CTG1_1'	181546281	Standard
# #		'HSCHR5_7_CTG1'	181544732	Standard
# #		'HSCHR5_1_CTG5'	181543736	Standard
# #		'HSCHR5_9_CTG1'	181543440	Standard
# #		'HSCHR5_3_CTG1'	181542495	Standard
# #		'HSCHR5_2_CTG5'	181542206	Standard
# #		'HSCHR5_6_CTG1'	181540245	Standard
# #		'HSCHR5_5_CTG1'	181539933	Standard
# #		'HG30_PATCH'	181539112	Standard
# #		'HSCHR5_3_CTG5'	181538569	Standard
# #		'5'	181538259	Standard
# #		'HG1395_PATCH'	181537525	Standard
# #		'HSCHR5_4_CTG1'	181537434	Standard
# #		'HSCHR5_1_CTG1_1'	180863570	Standard
# #		'HSCHR5_2_CTG1_1'	180753562	Standard
# #		'HSCHR6_MHC_MCF_CTG1'	170976334	Standard
# #		'HSCHR6_MHC_MANN_CTG1'	170959829	Standard
# #		'HSCHR6_MHC_SSTO_CTG1'	170946136	Standard
# #		'HSCHR6_MHC_APD_CTG1'	170845044	Standard
# #		'HSCHR6_1_CTG3'	170836231	Standard
# #		'HSCHR6_1_CTG2'	170833811	Standard
# #		'HSCHR6_1_CTG6'	170818797	Standard
# #		'HG2072_PATCH'	170816182	Standard
# #		'HSCHR6_1_CTG9'	170815583	Standard
# #		'HSCHR6_1_CTG5'	170815302	Standard
# #		'HSCHR6_8_CTG1'	170813052	Standard
# #		'HSCHR6_1_CTG7'	170812567	Standard
# #		'HG2128_PATCH'	170811684	Standard
# #		'HSCHR6_1_CTG10'	170810830	Standard
# #		'HSCHR6_1_CTG8'	170810115	Standard
# #		'HSCHR6_1_CTG4'	170808607	Standard
# #		'HG2121_PATCH'	170808322	Standard
# #		'6'	170805979	Standard
# #		'HG2057_PATCH'	170805979	Standard
# #		'HSCHR6_MHC_DBB_CTG1'	170783898	Standard
# #		'HG1651_PATCH'	170779650	Standard
# #		'HG563_PATCH'	170759097	Standard
# #		'HSCHR6_MHC_QBL_CTG1'	170734801	Standard
# #		'HSCHR6_MHC_COX_CTG1'	170727598	Standard
# #		'HSCHR7_3_CTG4_4'	159441130	Standard
# #		'HSCHR7_2_CTG6'	159407160	Standard
# #		'HG1309_PATCH'	159365091	Standard
# #		'HSCHR7_3_CTG1'	159352526	Standard
# #		'HSCHR7_1_CTG6'	159351981	Standard
# #		'HG2088_PATCH'	159351667	Standard
# #		'HSCHR7_2_CTG7'	159349352	Standard
# #		'HSCHR7_1_CTG1'	159349278	Standard
# #		'HSCHR7_1_CTG4_4'	159348604	Standard
# #		'HSCHR7_2_CTG1'	159348294	Standard
# #		'HSCHR7_1_CTG7'	159346281	Standard
# #		'HG2266_PATCH'	159346106	Standard
# #		'7'	159345973	Standard
# #		'HG2239_PATCH'	159345319	Standard
# #		'HSCHR7_3_CTG6'	159344441	Standard
# #		'HSCHR7_2_CTG4_4'	159333789	Standard
# #		'HG708_PATCH'	159270839	Standard
# #		'HSCHRX_2_CTG12'	156053172	Standard
# #		'HSCHRX_3_CTG7'	156050387	Standard
# #		'HSCHRX_1_CTG3'	156043585	Standard
# #		'X'	156040895	Standard
# #		'HSCHRX_2_CTG3'	156039875	Standard
# #		'HG1507_PATCH'	155996656	Standard
# #		'HG1506_PATCH'	155994589	Standard
# #		'HG1509_PATCH'	155994530	Standard
# #		'HG439_PATCH'	155960230	Standard
# #		'HG1466_PATCH'	155848651	Standard
# #		'HSCHR8_1_CTG6'	145150400	Standard
# #		'HSCHR8_7_CTG7'	145147686	Standard
# #		'HSCHR8_5_CTG7'	145144538	Standard
# #		'HG2067_PATCH'	145144434	Standard
# #		'HSCHR8_4_CTG7'	145143933	Standard
# #		'HSCHR8_1_CTG7'	145142033	Standard
# #		'HSCHR8_2_CTG7'	145141868	Standard
# #		'HSCHR8_6_CTG7'	145141837	Standard
# #		'HSCHR8_2_CTG1'	145141567	Standard
# #		'HSCHR8_4_CTG1'	145141010	Standard
# #		'HG2068_PATCH'	145140411	Standard
# #		'8'	145138636	Standard
# #		'HG2419_PATCH'	145138635	Standard
# #		'HSCHR8_7_CTG1'	145138198	Standard
# #		'HSCHR8_5_CTG1'	145137619	Standard
# #		'HSCHR8_6_CTG1'	145136257	Standard
# #		'HSCHR8_3_CTG1'	145130612	Standard
# #		'HSCHR8_3_CTG7'	145125643	Standard
# #		'HSCHR8_1_CTG1'	145124952	Standard
# #		'HSCHR8_8_CTG1'	145123326	Standard
# #		'HSCHR8_9_CTG1'	144983589	Standard
# #		'HG76_PATCH'	144938989	Standard
# #		'HSCHR9_1_CTG1'	138409529	Standard
# #		'HSCHR9_1_CTG4'	138405815	Standard
# #		'HSCHR9_1_CTG5'	138404305	Standard
# #		'HSCHR9_1_CTG2'	138402913	Standard
# #		'HSCHR9_1_CTG3'	138400797	Standard
# #		'HSCHR9_1_CTG6'	138399532	Standard
# #		'HSCHR9_1_CTG7'	138399111	Standard
# #		'HG613_PATCH'	138394874	Standard
# #		'HG2030_PATCH'	138394865	Standard
# #		'9'	138394717	Standard
# #		'HSCHR11_2_CTG8'	135117433	Standard
# #		'HG151_NOVEL_TEST'	135097696	Standard
# #		'HSCHR11_1_CTG5'	135097255	Standard
# #		'HSCHR11_1_CTG1_2'	135096748	Standard
# #		'HG142_HG150_NOVEL_TEST'	135094228	Standard
# #		'HSCHR11_2_CTG1'	135093444	Standard
# #		'HSCHR11_1_CTG1_1'	135092355	Standard
# #		'HSCHR11_1_CTG6'	135092332	Standard
# #		'HSCHR11_3_CTG1'	135092180	Standard
# #		'HG2115_PATCH'	135092089	Standard
# #		'HG2114_PATCH'	135091163	Standard
# #		'HSCHR11_1_CTG3_1'	135090845	Standard
# #		'HG2116_PATCH'	135090698	Standard
# #		'HSCHR11_1_CTG3'	135090275	Standard
# #		'HG2111_PATCH'	135089248	Standard
# #		'HG28_PATCH'	135088641	Standard
# #		'HG107_PATCH'	135088590	Standard
# #		'HSCHR11_1_CTG8'	135088433	Standard
# #		'HG1521_PATCH'	135087279	Standard
# #		'11'	135086622	Standard
# #		'HG2217_PATCH'	135086621	Standard
# #		'HG1708_PATCH'	135086620	Standard
# #		'HG2060_PATCH'	135086593	Standard
# #		'HSCHR11_1_CTG7'	135085484	Standard
# #		'HSCHR11_2_CTG1_1'	135083841	Standard
# #		'HSCHR11_1_CTG2'	135083598	Standard
# #		'HG1445_PATCH'	135063159	Standard
# #		'HSCHR10_1_CTG1'	133844722	Standard
# #		'HG545_PATCH'	133833661	Standard
# #		'HSCHR10_1_CTG4'	133815819	Standard
# #		'HSCHR10_1_CTG2'	133813485	Standard
# #		'HSCHR10_1_CTG6'	133801239	Standard
# #		'HG2191_PATCH'	133799479	Standard
# #		'HG2244_HG2245_PATCH'	133797425	Standard
# #		'10'	133797422	Standard
# #		'HG2334_PATCH'	133797389	Standard
# #		'HG2242_HG2243_PATCH'	133797297	Standard
# #		'HG2241_PATCH'	133792722	Standard
# #		'HSCHR10_1_CTG3'	133783218	Standard
# #		'HG1277_PATCH'	133754853	Standard
# #		'HSCHR12_2_CTG2'	133307257	Standard
# #		'HSCHR12_9_CTG2_1'	133289677	Standard
# #		'HSCHR12_7_CTG2_1'	133289478	Standard
# #		'HSCHR12_1_CTG2_1'	133284468	Standard
# #		'HSCHR12_8_CTG2_1'	133282605	Standard
# #		'HSCHR12_2_CTG2_1'	133282358	Standard
# #		'HSCHR12_2_CTG1'	133282237	Standard
# #		'HSCHR12_3_CTG2_1'	133281486	Standard
# #		'HSCHR12_1_CTG2'	133281368	Standard
# #		'HSCHR12_4_CTG2_1'	133281351	Standard
# #		'HG1815_PATCH'	133281281	Standard
# #		'HSCHR12_5_CTG2_1'	133279478	Standard
# #		'HSCHR12_1_CTG1'	133279324	Standard
# #		'HSCHR12_4_CTG2'	133277582	Standard
# #		'HSCHR12_6_CTG2_1'	133275361	Standard
# #		'HG1362_PATCH'	133275314	Standard
# #		'12'	133275309	Standard
# #		'HG2047_PATCH'	133275304	Standard
# #		'HSCHR12_5_CTG2'	133275237	Standard
# #		'HG23_PATCH'	133275184	Standard
# #		'HG2063_PATCH'	133275140	Standard
# #		'HG2246_HG2248_HG2276_PATCH'	133274640	Standard
# #		'HG1398_PATCH'	133274540	Standard
# #		'HG2247_PATCH'	133274000	Standard
# #		'HSCHR12_3_CTG2'	133271566	Standard
# #		'HG2291_PATCH'	114534236	Standard
# #		'HG1523_PATCH'	114458500	Standard
# #		'HG2216_PATCH'	114376428	Standard
# #		'HSCHR13_1_CTG7'	114374491	Standard
# #		'HSCHR13_1_CTG3'	114370226	Standard
# #		'HG1817_1_PATCH'	114369395	Standard
# #		'HSCHR13_1_CTG8'	114368996	Standard
# #		'HSCHR13_1_CTG4'	114368332	Standard
# #		'HSCHR13_1_CTG2'	114368315	Standard
# #		'HSCHR13_1_CTG6'	114367169	Standard
# #		'HSCHR13_1_CTG5'	114365350	Standard
# #		'13'	114364328	Standard
# #		'HG2509_PATCH'	114364327	Standard
# #		'HG2249_PATCH'	114364211	Standard
# #		'HG2288_HG2289_PATCH'	114360394	Standard
# #		'HSCHR13_1_CTG1'	114348172	Standard
# #		'HG1524_PATCH'	114315104	Standard
# #		'HSCHR14_3_CTG1'	107067894	Standard
# #		'HSCHR14_2_CTG1'	107050862	Standard
# #		'HSCHR14_8_CTG1'	107050407	Standard
# #		'HSCHR14_9_CTG1'	107050362	Standard
# #		'HSCHR14_1_CTG1'	107047377	Standard
# #		'HSCHR14_7_CTG1'	107045728	Standard
# #		'14'	107043718	Standard
# #		'HG1_PATCH'	107043717	Standard
# #		'HG2510_PATCH'	107043717	Standard
# #		'HG2365_PATCH'	102714182	Standard
# #		'HSCHR15_4_CTG8'	102071387	Standard
# #		'HSCHR15_5_CTG8'	102070278	Standard
# #		'HSCHR15_2_CTG8'	102003326	Standard
# #		'HSCHR15_1_CTG8'	102002809	Standard
# #		'HG2499_PATCH'	102001626	Standard
# #		'HSCHR15_3_CTG8'	101999716	Standard
# #		'HSCHR15_1_CTG1'	101998275	Standard
# #		'HSCHR15_2_CTG3'	101995966	Standard
# #		'HSCHR15_1_CTG3'	101994657	Standard
# #		'HSCHR15_3_CTG3'	101993763	Standard
# #		'HG2198_PATCH'	101993033	Standard
# #		'15'	101991189	Standard
# #		'HG2511_PATCH'	101991188	Standard
# #		'HSCHR15_6_CTG8'	101521929	Standard
# #		'HG926_PATCH'	90680781	Standard
# #		'HSCHR16_1_CTG1'	90426449	Standard
# #		'HSCHR16_3_CTG3_1'	90346170	Standard
# #		'HSCHR16_5_CTG1'	90344275	Standard
# #		'HSCHR16_2_CTG3_1'	90343477	Standard
# #		'HSCHR16_4_CTG3_1'	90343133	Standard
# #		'HSCHR16_CTG2'	90341867	Standard
# #		'HG2471_PATCH'	90341128	Standard
# #		'HSCHR16_4_CTG1'	90340369	Standard
# #		'HSCHR16_3_CTG1'	90340304	Standard
# #		'HG2263_PATCH'	90338583	Standard
# #		'HSCHR16_5_CTG3_1'	90338377	Standard
# #		'16'	90338345	Standard
# #		'HSCHR16_1_CTG3_1'	90335239	Standard
# #		'HSCHR17_1_CTG5'	83552665	Standard
# #		'HSCHR17_10_CTG4'	83359087	Standard
# #		'HSCHR17_1_CTG1'	83290495	Standard
# #		'HSCHR17_12_CTG4'	83271781	Standard
# #		'HSCHR17_3_CTG4'	83269063	Standard
# #		'HSCHR17_3_CTG1'	83267046	Standard
# #		'HSCHR17_11_CTG4'	83264946	Standard
# #		'HSCHR17_1_CTG4'	83264766	Standard
# #		'HSCHR17_9_CTG4'	83263791	Standard
# #		'HSCHR17_2_CTG4'	83263494	Standard
# #		'HG2087_PATCH'	83260478	Standard
# #		'HSCHR17_2_CTG1'	83259496	Standard
# #		'HSCHR17_8_CTG4'	83258474	Standard
# #		'HSCHR17_3_CTG2'	83258211	Standard
# #		'HSCHR17_4_CTG4'	83257896	Standard
# #		'17'	83257441	Standard
# #		'HG2046_PATCH'	83257439	Standard
# #		'HSCHR17_1_CTG2'	83256362	Standard
# #		'HSCHR17_1_CTG9'	83255504	Standard
# #		'HSCHR17_5_CTG4'	83247119	Standard
# #		'HSCHR17_6_CTG4'	83246071	Standard
# #		'HG2285_HG106_HG2252_PATCH'	83219555	Standard
# #		'HG1320_PATCH'	83207673	Standard
# #		'HSCHR17_2_CTG2'	83160220	Standard
# #		'HSCHR17_2_CTG5'	83086355	Standard
# #		'HSCHR17_7_CTG4'	83058228	Standard
# #		'HSCHR18_2_CTG2'	80442734	Standard
# #		'HSCHR18_1_CTG1'	80395815	Standard
# #		'HSCHR18_1_CTG2'	80386177	Standard
# #		'HSCHR18_1_CTG2_1'	80382671	Standard
# #		'HSCHR18_1_CTG1_1'	80380517	Standard
# #		'HSCHR18_2_CTG1_1'	80379367	Standard
# #		'HG2442_PATCH'	80379182	Standard
# #		'HSCHR18_3_CTG2_1'	80379039	Standard
# #		'HSCHR18_5_CTG1_1'	80378965	Standard
# #		'HSCHR18_2_CTG2_1'	80378720	Standard
# #		'HSCHR18_4_CTG1_1'	80378406	Standard
# #		'HG2213_PATCH'	80377536	Standard
# #		'HSCHR18_ALT2_CTG2_1'	80376883	Standard
# #		'HSCHR18_ALT21_CTG2_1'	80376343	Standard
# #		'18'	80373285	Standard
# #		'HG2412_PATCH'	80373284	Standard
# #		'HSCHR20_1_CTG1'	64450183	Standard
# #		'HSCHR20_1_CTG3'	64447812	Standard
# #		'HSCHR20_1_CTG4'	64446453	Standard
# #		'20'	64444167	Standard
# #		'HSCHR20_1_CTG2'	64441059	Standard
# #		'HSCHR19KIR_CA01-TB04_CTG3_1'	58750420	Standard
# #		'HSCHR19KIR_FH15_B_HAP_CTG3_1'	58689284	Standard
# #		'HSCHR19KIR_FH05_B_HAP_CTG3_1'	58689016	Standard
# #		'HSCHR19KIR_0019-4656-B_CTG3_1'	58675214	Standard
# #		'HSCHR19KIR_FH13_BA2_HAP_CTG3_1'	58662330	Standard
# #		'HSCHR19KIR_RSH_BA2_HAP_CTG3_1'	58662237	Standard
# #		'HSCHR19KIR_G248_BA2_HAP_CTG3_1'	58661364	Standard
# #		'HSCHR19LRC_LRC_J_CTG3_1'	58650772	Standard
# #		'HSCHR19KIR_FH08_BAX_HAP_CTG3_1'	58647709	Standard
# #		'HSCHR19KIR_CA01-TB01_CTG3_1'	58645065	Standard
# #		'HSCHR19KIR_GRC212_AB_HAP_CTG3_1'	58644315	Standard
# #		'HG2021_PATCH'	58632883	Standard
# #		'HSCHR19KIR_LUCE_BDEL_HAP_CTG3_1'	58631446	Standard
# #		'HSCHR19KIR_RP5_B_HAP_CTG3_1'	58631402	Standard
# #		'HSCHR19KIR_T7526_BDEL_HAP_CTG3_1'	58631206	Standard
# #		'HSCHR19_2_CTG2'	58627095	Standard
# #		'HSCHR19_3_CTG3_1'	58625958	Standard
# #		'HSCHR19_3_CTG2'	58625823	Standard
# #		'HSCHR19_4_CTG3_1'	58625731	Standard
# #		'HSCHR19LRC_LRC_S_CTG3_1'	58625321	Standard
# #		'HSCHR19_1_CTG3_1'	58624789	Standard
# #		'HSCHR19_1_CTG2'	58624032	Standard
# #		'HSCHR19LRC_LRC_I_CTG3_1'	58623235	Standard
# #		'HSCHR19_4_CTG2'	58619803	Standard
# #		'HSCHR19_5_CTG2'	58619095	Standard
# #		'HSCHR19_2_CTG3_1'	58618601	Standard
# #		'HSCHR19KIR_ABC08_AB_HAP_C_P_CTG3_1'	58618008	Standard
# #		'HG109_PATCH'	58617934	Standard
# #		'HSCHR19KIR_FH08_A_HAP_CTG3_1'	58617658	Standard
# #		'HG26_PATCH'	58617652	Standard
# #		'HSCHR19KIR_G248_A_HAP_CTG3_1'	58617652	Standard
# #		'HSCHR19KIR_7191059-1_CTG3_1'	58617649	Standard
# #		'HSCHR19KIR_CA01-TA01_2_CTG3_1'	58617647	Standard
# #		'HSCHR19KIR_ABC08_AB_HAP_T_P_CTG3_1'	58617636	Standard
# #		'HSCHR19KIR_LUCE_A_HAP_CTG3_1'	58617634	Standard
# #		'HSCHR19KIR_CA01-TA01_1_CTG3_1'	58617632	Standard
# #		'HSCHR19KIR_HG2394_CTG3_1'	58617630	Standard
# #		'HSCHR19KIR_ABC08_A1_HAP_CTG3_1'	58617625	Standard
# #		'19'	58617616	Standard
# #		'HSCHR19KIR_RSH_A_HAP_CTG3_1'	58617616	Standard
# #		'HSCHR19KIR_502960008-1_CTG3_1'	58617609	Standard
# #		'HSCHR19KIR_7191059-2_CTG3_1'	58617604	Standard
# #		'HSCHR19KIR_G085_A_HAP_CTG3_1'	58617601	Standard
# #		'HSCHR19KIR_T7526_A_HAP_CTG3_1'	58617601	Standard
# #		'HSCHR19KIR_FH06_A_HAP_CTG3_1'	58617587	Standard
# #		'HSCHR19KIR_FH15_A_HAP_CTG3_1'	58617473	Standard
# #		'HSCHR19KIR_0019-4656-A_CTG3_1'	58617441	Standard
# #		'HSCHR19KIR_FH05_A_HAP_CTG3_1'	58616795	Standard
# #		'HSCHR19KIR_FH13_A_HAP_CTG3_1'	58616725	Standard
# #		'HSCHR19KIR_502960008-2_CTG3_1'	58616590	Standard
# #		'HSCHR19KIR_FH06_BA1_HAP_CTG3_1'	58603994	Standard
# #		'HSCHR19KIR_HG2396_CTG3_1'	58603982	Standard
# #		'HSCHR19KIR_G085_BA1_HAP_CTG3_1'	58603800	Standard
# #		'HSCHR19KIR_GRC212_BA1_HAP_CTG3_1'	58602595	Standard
# #		'HSCHR19KIR_HG2393_CTG3_1'	58583172	Standard
# #		'HSCHR19LRC_LRC_T_CTG3_1'	58561614	Standard
# #		'HSCHR19LRC_COX1_CTG3_1'	58546647	Standard
# #		'HSCHR19LRC_PGF1_CTG3_1'	58546031	Standard
# #		'HSCHR19KIR_0010-5217-AB_CTG3_1'	58538377	Standard
# #		'HSCHR19KIR_CA04_CTG3_1'	58537114	Standard
# #		'HSCHR19LRC_PGF2_CTG3_1'	58355410	Standard
# #		'HSCHR19LRC_COX2_CTG3_1'	58288451	Standard
# #		'HG2062_PATCH'	57262172	Standard
# #		'Y'	57227415	Standard
# #		'HG1535_PATCH'	57187419	Standard
# #		'HG1531_PATCH'	57177176	Standard
# #		'HG1485_PATCH'	50915261	Standard
# #		'HSCHR22_1_CTG7'	50872732	Standard
# #		'HSCHR22_7_CTG1'	50845852	Standard
# #		'HSCHR22_1_CTG6'	50842710	Standard
# #		'HSCHR22_5_CTG1'	50832153	Standard
# #		'HSCHR22_8_CTG1'	50832130	Standard
# #		'HSCHR22_2_CTG1'	50830603	Standard
# #		'HSCHR22_1_CTG3'	50827573	Standard
# #		'HSCHR22_1_CTG4'	50824699	Standard
# #		'HSCHR22_1_CTG5'	50821308	Standard
# #		'HG1311_PATCH'	50818486	Standard
# #		'HG494_PATCH'	50818473	Standard
# #		'22'	50818468	Standard
# #		'HSCHR22_3_CTG1'	50818468	Standard
# #		'HG2512_PATCH'	50818467	Standard
# #		'HSCHR22_6_CTG1'	50815919	Standard
# #		'HSCHR22_1_CTG1'	50806372	Standard
# #		'HSCHR22_4_CTG1'	50806321	Standard
# #		'HSCHR22_1_CTG2'	50788525	Standard
# #		'HG2513_PATCH'	47068079	Standard
# #		'HSCHR21_1_CTG1_1'	46722569	Standard
# #		'HSCHR21_4_CTG1_1'	46719541	Standard
# #		'HSCHR21_2_CTG1_1'	46716685	Standard
# #		'HSCHR21_3_CTG1_1'	46715777	Standard
# #		'HSCHR21_6_CTG1_1'	46713516	Standard
# #		'HSCHR21_8_CTG1_1'	46713185	Standard
# #		'HSCHR21_5_CTG2'	46712294	Standard
# #		'21'	46709983	Standard
# #		'KI270728.1'	1872759	Standard
# #		'KI270727.1'	448248	Standard
# #		'KI270442.1'	392061	Standard
# #		'KI270729.1'	280839	Standard
# #		'GL000225.1'	211173	Standard
# #		'KI270743.1'	210658	Standard
# #		'GL000008.2'	209709	Standard
# #		'GL000009.2'	201709	Standard
# #		'KI270747.1'	198735	Standard
# #		'KI270722.1'	194050	Standard
# #		'GL000194.1'	191469	Standard
# #		'KI270742.1'	186739	Standard
# #		'GL000205.2'	185591	Standard
# #		'GL000195.1'	182896	Standard
# #		'KI270736.1'	181920	Standard
# #		'KI270733.1'	179772	Standard
# #		'GL000224.1'	179693	Standard
# #		'GL000219.1'	179198	Standard
# #		'KI270719.1'	176845	Standard
# #		'GL000216.2'	176608	Standard
# #		'KI270712.1'	176043	Standard
# #		'KI270706.1'	175055	Standard
# #		'KI270725.1'	172810	Standard
# #		'KI270744.1'	168472	Standard
# #		'KI270734.1'	165050	Standard
# #		'GL000213.1'	164239	Standard
# #		'GL000220.1'	161802	Standard
# #		'KI270715.1'	161471	Standard
# #		'GL000218.1'	161147	Standard
# #		'KI270749.1'	158759	Standard
# #		'KI270741.1'	157432	Standard
# #		'GL000221.1'	155397	Standard
# #		'KI270716.1'	153799	Standard
# #		'KI270731.1'	150754	Standard
# #		'KI270751.1'	150742	Standard
# #		'KI270750.1'	148850	Standard
# #		'KI270519.1'	138126	Standard
# #		'GL000214.1'	137718	Standard
# #		'KI270708.1'	127682	Standard
# #		'KI270730.1'	112551	Standard
# #		'KI270438.1'	112505	Standard
# #		'KI270737.1'	103838	Standard
# #		'KI270721.1'	100316	Standard
# #		'KI270738.1'	99375	Standard
# #		'KI270748.1'	93321	Standard
# #		'KI270435.1'	92983	Standard
# #		'GL000208.1'	92689	Standard
# #		'KI270538.1'	91309	Standard
# #		'KI270756.1'	79590	Standard
# #		'KI270739.1'	73985	Standard
# #		'KI270757.1'	71251	Standard
# #		'KI270709.1'	66860	Standard
# #		'KI270746.1'	66486	Standard
# #		'KI270753.1'	62944	Standard
# #		'KI270589.1'	44474	Standard
# #		'KI270726.1'	43739	Standard
# #		'KI270735.1'	42811	Standard
# #		'KI270711.1'	42210	Standard
# #		'KI270745.1'	41891	Standard
# #		'KI270714.1'	41717	Standard
# #		'KI270732.1'	41543	Standard
# #		'KI270713.1'	40745	Standard
# #		'KI270754.1'	40191	Standard
# #		'KI270710.1'	40176	Standard
# #		'KI270717.1'	40062	Standard
# #		'KI270724.1'	39555	Standard
# #		'KI270720.1'	39050	Standard
# #		'KI270723.1'	38115	Standard
# #		'KI270718.1'	38054	Standard
# #		'KI270317.1'	37690	Standard
# #		'KI270740.1'	37240	Standard
# #		'KI270755.1'	36723	Standard
# #		'KI270707.1'	32032	Standard
# #		'KI270579.1'	31033	Standard
# #		'KI270752.1'	27745	Standard
# #		'KI270512.1'	22689	Standard
# #		'KI270322.1'	21476	Standard
# #		'MT'	16569	Standard
# #		'GL000226.1'	15008	Standard
# #		'KI270311.1'	12399	Standard
# #		'KI270366.1'	8320	Standard
# #		'KI270511.1'	8127	Standard
# #		'KI270448.1'	7992	Standard
# #		'KI270521.1'	7642	Standard
# #		'KI270581.1'	7046	Standard
# #		'KI270582.1'	6504	Standard
# #		'KI270515.1'	6361	Standard
# #		'KI270588.1'	6158	Standard
# #		'KI270591.1'	5796	Standard
# #		'KI270522.1'	5674	Standard
# #		'KI270507.1'	5353	Standard
# #		'KI270590.1'	4685	Standard
# #		'KI270584.1'	4513	Standard
# #		'KI270320.1'	4416	Standard
# #		'KI270382.1'	4215	Standard
# #		'KI270468.1'	4055	Standard
# #		'KI270467.1'	3920	Standard
# #		'KI270362.1'	3530	Standard
# #		'KI270517.1'	3253	Standard
# #		'KI270593.1'	3041	Standard
# #		'KI270528.1'	2983	Standard
# #		'KI270587.1'	2969	Standard
# #		'KI270364.1'	2855	Standard
# #		'KI270371.1'	2805	Standard
# #		'KI270333.1'	2699	Standard
# #		'KI270374.1'	2656	Standard
# #		'KI270411.1'	2646	Standard
# #		'KI270414.1'	2489	Standard
# #		'KI270510.1'	2415	Standard
# #		'KI270390.1'	2387	Standard
# #		'KI270375.1'	2378	Standard
# #		'KI270420.1'	2321	Standard
# #		'KI270509.1'	2318	Standard
# #		'KI270315.1'	2276	Standard
# #		'KI270302.1'	2274	Standard
# #		'KI270518.1'	2186	Standard
# #		'KI270530.1'	2168	Standard
# #		'KI270304.1'	2165	Standard
# #		'KI270418.1'	2145	Standard
# #		'KI270424.1'	2140	Standard
# #		'KI270417.1'	2043	Standard
# #		'KI270508.1'	1951	Standard
# #		'KI270303.1'	1942	Standard
# #		'KI270381.1'	1930	Standard
# #		'KI270529.1'	1899	Standard
# #		'KI270425.1'	1884	Standard
# #		'KI270396.1'	1880	Standard
# #		'KI270363.1'	1803	Standard
# #		'KI270386.1'	1788	Standard
# #		'KI270465.1'	1774	Standard
# #		'KI270383.1'	1750	Standard
# #		'KI270384.1'	1658	Standard
# #		'KI270330.1'	1652	Standard
# #		'KI270372.1'	1650	Standard
# #		'KI270548.1'	1599	Standard
# #		'KI270580.1'	1553	Standard
# #		'KI270387.1'	1537	Standard
# #		'KI270391.1'	1484	Standard
# #		'KI270305.1'	1472	Standard
# #		'KI270373.1'	1451	Standard
# #		'KI270422.1'	1445	Standard
# #		'KI270316.1'	1444	Standard
# #		'KI270338.1'	1428	Standard
# #		'KI270340.1'	1428	Standard
# #		'KI270583.1'	1400	Standard
# #		'KI270334.1'	1368	Standard
# #		'KI270429.1'	1361	Standard
# #		'KI270393.1'	1308	Standard
# #		'KI270516.1'	1300	Standard
# #		'KI270389.1'	1298	Standard
# #		'KI270466.1'	1233	Standard
# #		'KI270388.1'	1216	Standard
# #		'KI270544.1'	1202	Standard
# #		'KI270310.1'	1201	Standard
# #		'KI270412.1'	1179	Standard
# #		'KI270395.1'	1143	Standard
# #		'KI270376.1'	1136	Standard
# #		'KI270337.1'	1121	Standard
# #		'KI270335.1'	1048	Standard
# #		'KI270378.1'	1048	Standard
# #		'KI270379.1'	1045	Standard
# #		'KI270329.1'	1040	Standard
# #		'KI270419.1'	1029	Standard
# #		'KI270336.1'	1026	Standard
# #		'KI270312.1'	998	Standard
# #		'KI270539.1'	993	Standard
# #		'KI270385.1'	990	Standard
# #		'KI270423.1'	981	Standard
# #		'KI270392.1'	971	Standard
# #		'KI270394.1'	970	Standard
# #-----------------------------------------------
#
# 00:00:21 Predicting variants
# 00:00:21 Loading sequences for chromosome '12' from file '/home/mgpersonal/miniconda3/envs/ngs/share/snpeff-5.3.0a-1/./data/GRCh38.99/sequence.12.bin'
# 00:00:22 Building sequence tree for chromosome '12'
# 00:00:22 Done. Loaded 1488 sequences.
#
# WARNINGS: Some warning were detected
# Warning type	Number of warnings
# WARNING_TRANSCRIPT_NO_STOP_CODON	4
#
#
# 00:00:22 Creating summary file: snpEff_summary.html
# 00:00:23 Creating genes file: snpEff_genes.txt
# 00:00:23 done.
# 00:00:23 Done.
# 00:00:00 SnpEff version SnpEff 5.3a (build 2025-09-02 10:24), by Pablo Cingolani
# 00:00:00 Command: 'ann'
# 00:00:00 Reading configuration file 'snpEff.config'. Genome: 'GRCh38.99'
# 00:00:00 Looking for config file: '/home/mgpersonal/ctdna_kras_project/results/vcf/snpEff.config'
# 00:00:00 Reading config file: /home/mgpersonal/miniconda3/envs/ngs/share/snpeff-5.3.0a-1/snpEff.config
# 00:00:00 done
# 00:00:00 Reading database for genome version 'GRCh38.99' from file '/home/mgpersonal/miniconda3/envs/ngs/share/snpeff-5.3.0a-1/./data/GRCh38.99/snpEffectPredictor.bin' (this might take a while)
# 00:00:15 done
# 00:00:15 Loading Motifs and PWMs
# 00:00:15 Building interval forest
# 00:00:20 done.
# 00:00:20 Genome stats :
# #-----------------------------------------------
# # Genome name                : 'Homo_sapiens'
# # Genome version             : 'GRCh38.99'
# # Genome ID                  : 'GRCh38.99[0]'
# # Has protein coding info    : true
# # Has Tr. Support Level info : true
# # Genes                      : 60676
# # Protein coding genes       : 20135
# #-----------------------------------------------
# # Transcripts                : 227818
# # Avg. transcripts per gene  : 3.75
# # TSL transcripts            : 169199
# #-----------------------------------------------
# # Checked transcripts        :
# #               AA sequences : 100576 ( 119.03% )
# #              DNA sequences : 172288 ( 75.63% )
# #-----------------------------------------------
# # Protein coding transcripts : 84494
# #              Length errors :  13469 ( 15.94% )
# #  STOP codons in CDS errors :     34 ( 0.04% )
# #         START codon errors :   8149 ( 9.64% )
# #        STOP codon warnings :   7264 ( 8.60% )
# #              UTR sequences :  81637 ( 35.83% )
# #               Total Errors :  20119 ( 23.81% )
# #-----------------------------------------------
# # Cds                        : 764354
# # Exons                      : 1376499
# # Exons with sequence        : 1376499
# # Exons without sequence     : 0
# # Avg. exons per transcript  : 6.04
# # WARNING!                   : Mitochondrion chromosome 'MT' does not have a mitochondrion codon table (codon table = 'Standard'). You should update the config file.
# #-----------------------------------------------
# # Number of chromosomes      : 639
# # Chromosomes                : Format 'chromo_name size codon_table'
# #		'HSCHR1_2_CTG3'	248975002	Standard
# #		'HSCHR1_1_CTG31'	248973653	Standard
# #		'HSCHR1_2_CTG31'	248971826	Standard
# #		'HSCHR1_1_CTG3'	248968406	Standard
# #		'HSCHR1_3_CTG31'	248967909	Standard
# #		'HSCHR1_9_CTG3'	248965380	Standard
# #		'HSCHR1_4_CTG3'	248963886	Standard
# #		'HSCHR1_2_CTG32_1'	248962488	Standard
# #		'HSCHR1_8_CTG3'	248962151	Standard
# #		'HSCHR1_3_CTG3'	248961700	Standard
# #		'HSCHR1_1_CTG11'	248961539	Standard
# #		'HSCHR1_3_CTG32_1'	248960761	Standard
# #		'HSCHR1_5_CTG32_1'	248960213	Standard
# #		'HSCHR1_1_CTG32_1'	248960143	Standard
# #		'HG1832_PATCH'	248959779	Standard
# #		'HG2095_PATCH'	248959131	Standard
# #		'HSCHR1_ALT2_1_CTG32_1'	248958866	Standard
# #		'HSCHR1_4_CTG32_1'	248958766	Standard
# #		'HG2104_PATCH'	248958259	Standard
# #		'HG986_PATCH'	248956639	Standard
# #		'1'	248956422	Standard
# #		'HG2058_PATCH'	248956422	Standard
# #		'HSCHR1_6_CTG3'	248955842	Standard
# #		'HG460_PATCH'	248955838	Standard
# #		'HSCHR1_4_CTG31'	248955631	Standard
# #		'HG2002_PATCH'	248942227	Standard
# #		'HG1342_HG2282_PATCH'	248929249	Standard
# #		'HSCHR1_5_CTG3'	248926662	Standard
# #		'HG2290_PATCH'	242235269	Standard
# #		'HSCHR2_2_CTG7'	242223512	Standard
# #		'HSCHR2_1_CTG7_2'	242210518	Standard
# #		'HSCHR2_7_CTG7_2'	242202531	Standard
# #		'HSCHR2_5_CTG7_2'	242199685	Standard
# #		'HSCHR2_8_CTG7_2'	242199670	Standard
# #		'HSCHR2_2_CTG7_2'	242199609	Standard
# #		'HSCHR2_1_CTG5'	242199562	Standard
# #		'HSCHR2_1_CTG15'	242198904	Standard
# #		'HSCHR2_2_CTG15'	242198544	Standard
# #		'HSCHR2_2_CTG1'	242198346	Standard
# #		'HSCHR2_6_CTG7_2'	242198149	Standard
# #		'HSCHR2_4_CTG7_2'	242196589	Standard
# #		'HSCHR2_3_CTG1'	242195626	Standard
# #		'HG1384_PATCH'	242195459	Standard
# #		'HSCHR2_1_CTG1'	242194896	Standard
# #		'HSCHR2_3_CTG7_2'	242194557	Standard
# #		'HSCHR2_3_CTG15'	242194292	Standard
# #		'HG721_PATCH'	242194216	Standard
# #		'HSCHR2_1_CTG7'	242193540	Standard
# #		'HG2233_PATCH'	242193535	Standard
# #		'2'	242193529	Standard
# #		'HG2232_PATCH'	242193529	Standard
# #		'HSCHR2_4_CTG1'	242191076	Standard
# #		'HSCHR3_4_CTG1'	198310749	Standard
# #		'HSCHR3_1_CTG2_1'	198306097	Standard
# #		'HSCHR3_5_CTG1'	198305844	Standard
# #		'HSCHR3_6_CTG2_1'	198305007	Standard
# #		'HSCHR3_1_CTG3'	198302882	Standard
# #		'HSCHR3_9_CTG2_1'	198302489	Standard
# #		'HSCHR3_8_CTG2_1'	198302280	Standard
# #		'HSCHR3_4_CTG2_1'	198301383	Standard
# #		'HSCHR3_7_CTG2_1'	198301024	Standard
# #		'HSCHR3_5_CTG2_1'	198300594	Standard
# #		'HSCHR3_3_CTG2_1'	198300421	Standard
# #		'HSCHR3_3_CTG1'	198300110	Standard
# #		'HG2133_PATCH'	198299611	Standard
# #		'HSCHR3_2_CTG2_1'	198298736	Standard
# #		'HSCHR3_1_CTG1'	198297480	Standard
# #		'HSCHR3_2_CTG3'	198296961	Standard
# #		'HSCHR3_4_CTG3'	198296867	Standard
# #		'HG2022_PATCH'	198295941	Standard
# #		'HSCHR3_8_CTG3'	198295934	Standard
# #		'HG126_PATCH'	198295908	Standard
# #		'HG2235_PATCH'	198295655	Standard
# #		'3'	198295559	Standard
# #		'HG2066_PATCH'	198295555	Standard
# #		'HG2236_PATCH'	198295537	Standard
# #		'HSCHR3_6_CTG3'	198294921	Standard
# #		'HSCHR3_7_CTG3'	198294497	Standard
# #		'HSCHR3_5_CTG3'	198293785	Standard
# #		'HSCHR3_3_CTG3'	198293223	Standard
# #		'HSCHR3_9_CTG3'	198291952	Standard
# #		'HG2237_PATCH'	198290329	Standard
# #		'HG2525_PATCH'	190293418	Standard
# #		'HSCHR4_11_CTG12'	190233769	Standard
# #		'HSCHR4_1_CTG12'	190227204	Standard
# #		'HSCHR4_7_CTG12'	190225141	Standard
# #		'HSCHR4_1_CTG6'	190224838	Standard
# #		'HSCHR4_1_CTG4'	190221757	Standard
# #		'HSCHR4_12_CTG12'	190221648	Standard
# #		'HSCHR4_4_CTG12'	190220704	Standard
# #		'HSCHR4_5_CTG12'	190219562	Standard
# #		'HSCHR4_9_CTG12'	190219005	Standard
# #		'HSCHR4_1_CTG8_1'	190218838	Standard
# #		'HSCHR4_6_CTG12'	190218533	Standard
# #		'HSCHR4_8_CTG12'	190218480	Standard
# #		'HSCHR4_3_CTG12'	190218028	Standard
# #		'HSCHR4_2_CTG4'	190217898	Standard
# #		'4'	190214555	Standard
# #		'HG699_PATCH'	190211220	Standard
# #		'HG1296_PATCH'	190208697	Standard
# #		'HSCHR4_2_CTG12'	190206797	Standard
# #		'HG1299_PATCH'	190201596	Standard
# #		'HG1298_PATCH'	190196285	Standard
# #		'HG705_PATCH'	190172551	Standard
# #		'HG2023_PATCH'	190147504	Standard
# #		'HSCHR4_1_CTG9'	190096932	Standard
# #		'HSCHR5_8_CTG1'	181668817	Standard
# #		'HSCHR5_1_CTG1'	181558402	Standard
# #		'HSCHR5_3_CTG1_1'	181554865	Standard
# #		'HSCHR5_2_CTG1'	181547139	Standard
# #		'HSCHR5_4_CTG1_1'	181546281	Standard
# #		'HSCHR5_7_CTG1'	181544732	Standard
# #		'HSCHR5_1_CTG5'	181543736	Standard
# #		'HSCHR5_9_CTG1'	181543440	Standard
# #		'HSCHR5_3_CTG1'	181542495	Standard
# #		'HSCHR5_2_CTG5'	181542206	Standard
# #		'HSCHR5_6_CTG1'	181540245	Standard
# #		'HSCHR5_5_CTG1'	181539933	Standard
# #		'HG30_PATCH'	181539112	Standard
# #		'HSCHR5_3_CTG5'	181538569	Standard
# #		'5'	181538259	Standard
# #		'HG1395_PATCH'	181537525	Standard
# #		'HSCHR5_4_CTG1'	181537434	Standard
# #		'HSCHR5_1_CTG1_1'	180863570	Standard
# #		'HSCHR5_2_CTG1_1'	180753562	Standard
# #		'HSCHR6_MHC_MCF_CTG1'	170976334	Standard
# #		'HSCHR6_MHC_MANN_CTG1'	170959829	Standard
# #		'HSCHR6_MHC_SSTO_CTG1'	170946136	Standard
# #		'HSCHR6_MHC_APD_CTG1'	170845044	Standard
# #		'HSCHR6_1_CTG3'	170836231	Standard
# #		'HSCHR6_1_CTG2'	170833811	Standard
# #		'HSCHR6_1_CTG6'	170818797	Standard
# #		'HG2072_PATCH'	170816182	Standard
# #		'HSCHR6_1_CTG9'	170815583	Standard
# #		'HSCHR6_1_CTG5'	170815302	Standard
# #		'HSCHR6_8_CTG1'	170813052	Standard
# #		'HSCHR6_1_CTG7'	170812567	Standard
# #		'HG2128_PATCH'	170811684	Standard
# #		'HSCHR6_1_CTG10'	170810830	Standard
# #		'HSCHR6_1_CTG8'	170810115	Standard
# #		'HSCHR6_1_CTG4'	170808607	Standard
# #		'HG2121_PATCH'	170808322	Standard
# #		'6'	170805979	Standard
# #		'HG2057_PATCH'	170805979	Standard
# #		'HSCHR6_MHC_DBB_CTG1'	170783898	Standard
# #		'HG1651_PATCH'	170779650	Standard
# #		'HG563_PATCH'	170759097	Standard
# #		'HSCHR6_MHC_QBL_CTG1'	170734801	Standard
# #		'HSCHR6_MHC_COX_CTG1'	170727598	Standard
# #		'HSCHR7_3_CTG4_4'	159441130	Standard
# #		'HSCHR7_2_CTG6'	159407160	Standard
# #		'HG1309_PATCH'	159365091	Standard
# #		'HSCHR7_3_CTG1'	159352526	Standard
# #		'HSCHR7_1_CTG6'	159351981	Standard
# #		'HG2088_PATCH'	159351667	Standard
# #		'HSCHR7_2_CTG7'	159349352	Standard
# #		'HSCHR7_1_CTG1'	159349278	Standard
# #		'HSCHR7_1_CTG4_4'	159348604	Standard
# #		'HSCHR7_2_CTG1'	159348294	Standard
# #		'HSCHR7_1_CTG7'	159346281	Standard
# #		'HG2266_PATCH'	159346106	Standard
# #		'7'	159345973	Standard
# #		'HG2239_PATCH'	159345319	Standard
# #		'HSCHR7_3_CTG6'	159344441	Standard
# #		'HSCHR7_2_CTG4_4'	159333789	Standard
# #		'HG708_PATCH'	159270839	Standard
# #		'HSCHRX_2_CTG12'	156053172	Standard
# #		'HSCHRX_3_CTG7'	156050387	Standard
# #		'HSCHRX_1_CTG3'	156043585	Standard
# #		'X'	156040895	Standard
# #		'HSCHRX_2_CTG3'	156039875	Standard
# #		'HG1507_PATCH'	155996656	Standard
# #		'HG1506_PATCH'	155994589	Standard
# #		'HG1509_PATCH'	155994530	Standard
# #		'HG439_PATCH'	155960230	Standard
# #		'HG1466_PATCH'	155848651	Standard
# #		'HSCHR8_1_CTG6'	145150400	Standard
# #		'HSCHR8_7_CTG7'	145147686	Standard
# #		'HSCHR8_5_CTG7'	145144538	Standard
# #		'HG2067_PATCH'	145144434	Standard
# #		'HSCHR8_4_CTG7'	145143933	Standard
# #		'HSCHR8_1_CTG7'	145142033	Standard
# #		'HSCHR8_2_CTG7'	145141868	Standard
# #		'HSCHR8_6_CTG7'	145141837	Standard
# #		'HSCHR8_2_CTG1'	145141567	Standard
# #		'HSCHR8_4_CTG1'	145141010	Standard
# #		'HG2068_PATCH'	145140411	Standard
# #		'8'	145138636	Standard
# #		'HG2419_PATCH'	145138635	Standard
# #		'HSCHR8_7_CTG1'	145138198	Standard
# #		'HSCHR8_5_CTG1'	145137619	Standard
# #		'HSCHR8_6_CTG1'	145136257	Standard
# #		'HSCHR8_3_CTG1'	145130612	Standard
# #		'HSCHR8_3_CTG7'	145125643	Standard
# #		'HSCHR8_1_CTG1'	145124952	Standard
# #		'HSCHR8_8_CTG1'	145123326	Standard
# #		'HSCHR8_9_CTG1'	144983589	Standard
# #		'HG76_PATCH'	144938989	Standard
# #		'HSCHR9_1_CTG1'	138409529	Standard
# #		'HSCHR9_1_CTG4'	138405815	Standard
# #		'HSCHR9_1_CTG5'	138404305	Standard
# #		'HSCHR9_1_CTG2'	138402913	Standard
# #		'HSCHR9_1_CTG3'	138400797	Standard
# #		'HSCHR9_1_CTG6'	138399532	Standard
# #		'HSCHR9_1_CTG7'	138399111	Standard
# #		'HG613_PATCH'	138394874	Standard
# #		'HG2030_PATCH'	138394865	Standard
# #		'9'	138394717	Standard
# #		'HSCHR11_2_CTG8'	135117433	Standard
# #		'HG151_NOVEL_TEST'	135097696	Standard
# #		'HSCHR11_1_CTG5'	135097255	Standard
# #		'HSCHR11_1_CTG1_2'	135096748	Standard
# #		'HG142_HG150_NOVEL_TEST'	135094228	Standard
# #		'HSCHR11_2_CTG1'	135093444	Standard
# #		'HSCHR11_1_CTG1_1'	135092355	Standard
# #		'HSCHR11_1_CTG6'	135092332	Standard
# #		'HSCHR11_3_CTG1'	135092180	Standard
# #		'HG2115_PATCH'	135092089	Standard
# #		'HG2114_PATCH'	135091163	Standard
# #		'HSCHR11_1_CTG3_1'	135090845	Standard
# #		'HG2116_PATCH'	135090698	Standard
# #		'HSCHR11_1_CTG3'	135090275	Standard
# #		'HG2111_PATCH'	135089248	Standard
# #		'HG28_PATCH'	135088641	Standard
# #		'HG107_PATCH'	135088590	Standard
# #		'HSCHR11_1_CTG8'	135088433	Standard
# #		'HG1521_PATCH'	135087279	Standard
# #		'11'	135086622	Standard
# #		'HG2217_PATCH'	135086621	Standard
# #		'HG1708_PATCH'	135086620	Standard
# #		'HG2060_PATCH'	135086593	Standard
# #		'HSCHR11_1_CTG7'	135085484	Standard
# #		'HSCHR11_2_CTG1_1'	135083841	Standard
# #		'HSCHR11_1_CTG2'	135083598	Standard
# #		'HG1445_PATCH'	135063159	Standard
# #		'HSCHR10_1_CTG1'	133844722	Standard
# #		'HG545_PATCH'	133833661	Standard
# #		'HSCHR10_1_CTG4'	133815819	Standard
# #		'HSCHR10_1_CTG2'	133813485	Standard
# #		'HSCHR10_1_CTG6'	133801239	Standard
# #		'HG2191_PATCH'	133799479	Standard
# #		'HG2244_HG2245_PATCH'	133797425	Standard
# #		'10'	133797422	Standard
# #		'HG2334_PATCH'	133797389	Standard
# #		'HG2242_HG2243_PATCH'	133797297	Standard
# #		'HG2241_PATCH'	133792722	Standard
# #		'HSCHR10_1_CTG3'	133783218	Standard
# #		'HG1277_PATCH'	133754853	Standard
# #		'HSCHR12_2_CTG2'	133307257	Standard
# #		'HSCHR12_9_CTG2_1'	133289677	Standard
# #		'HSCHR12_7_CTG2_1'	133289478	Standard
# #		'HSCHR12_1_CTG2_1'	133284468	Standard
# #		'HSCHR12_8_CTG2_1'	133282605	Standard
# #		'HSCHR12_2_CTG2_1'	133282358	Standard
# #		'HSCHR12_2_CTG1'	133282237	Standard
# #		'HSCHR12_3_CTG2_1'	133281486	Standard
# #		'HSCHR12_1_CTG2'	133281368	Standard
# #		'HSCHR12_4_CTG2_1'	133281351	Standard
# #		'HG1815_PATCH'	133281281	Standard
# #		'HSCHR12_5_CTG2_1'	133279478	Standard
# #		'HSCHR12_1_CTG1'	133279324	Standard
# #		'HSCHR12_4_CTG2'	133277582	Standard
# #		'HSCHR12_6_CTG2_1'	133275361	Standard
# #		'HG1362_PATCH'	133275314	Standard
# #		'12'	133275309	Standard
# #		'HG2047_PATCH'	133275304	Standard
# #		'HSCHR12_5_CTG2'	133275237	Standard
# #		'HG23_PATCH'	133275184	Standard
# #		'HG2063_PATCH'	133275140	Standard
# #		'HG2246_HG2248_HG2276_PATCH'	133274640	Standard
# #		'HG1398_PATCH'	133274540	Standard
# #		'HG2247_PATCH'	133274000	Standard
# #		'HSCHR12_3_CTG2'	133271566	Standard
# #		'HG2291_PATCH'	114534236	Standard
# #		'HG1523_PATCH'	114458500	Standard
# #		'HG2216_PATCH'	114376428	Standard
# #		'HSCHR13_1_CTG7'	114374491	Standard
# #		'HSCHR13_1_CTG3'	114370226	Standard
# #		'HG1817_1_PATCH'	114369395	Standard
# #		'HSCHR13_1_CTG8'	114368996	Standard
# #		'HSCHR13_1_CTG4'	114368332	Standard
# #		'HSCHR13_1_CTG2'	114368315	Standard
# #		'HSCHR13_1_CTG6'	114367169	Standard
# #		'HSCHR13_1_CTG5'	114365350	Standard
# #		'13'	114364328	Standard
# #		'HG2509_PATCH'	114364327	Standard
# #		'HG2249_PATCH'	114364211	Standard
# #		'HG2288_HG2289_PATCH'	114360394	Standard
# #		'HSCHR13_1_CTG1'	114348172	Standard
# #		'HG1524_PATCH'	114315104	Standard
# #		'HSCHR14_3_CTG1'	107067894	Standard
# #		'HSCHR14_2_CTG1'	107050862	Standard
# #		'HSCHR14_8_CTG1'	107050407	Standard
# #		'HSCHR14_9_CTG1'	107050362	Standard
# #		'HSCHR14_1_CTG1'	107047377	Standard
# #		'HSCHR14_7_CTG1'	107045728	Standard
# #		'14'	107043718	Standard
# #		'HG1_PATCH'	107043717	Standard
# #		'HG2510_PATCH'	107043717	Standard
# #		'HG2365_PATCH'	102714182	Standard
# #		'HSCHR15_4_CTG8'	102071387	Standard
# #		'HSCHR15_5_CTG8'	102070278	Standard
# #		'HSCHR15_2_CTG8'	102003326	Standard
# #		'HSCHR15_1_CTG8'	102002809	Standard
# #		'HG2499_PATCH'	102001626	Standard
# #		'HSCHR15_3_CTG8'	101999716	Standard
# #		'HSCHR15_1_CTG1'	101998275	Standard
# #		'HSCHR15_2_CTG3'	101995966	Standard
# #		'HSCHR15_1_CTG3'	101994657	Standard
# #		'HSCHR15_3_CTG3'	101993763	Standard
# #		'HG2198_PATCH'	101993033	Standard
# #		'15'	101991189	Standard
# #		'HG2511_PATCH'	101991188	Standard
# #		'HSCHR15_6_CTG8'	101521929	Standard
# #		'HG926_PATCH'	90680781	Standard
# #		'HSCHR16_1_CTG1'	90426449	Standard
# #		'HSCHR16_3_CTG3_1'	90346170	Standard
# #		'HSCHR16_5_CTG1'	90344275	Standard
# #		'HSCHR16_2_CTG3_1'	90343477	Standard
# #		'HSCHR16_4_CTG3_1'	90343133	Standard
# #		'HSCHR16_CTG2'	90341867	Standard
# #		'HG2471_PATCH'	90341128	Standard
# #		'HSCHR16_4_CTG1'	90340369	Standard
# #		'HSCHR16_3_CTG1'	90340304	Standard
# #		'HG2263_PATCH'	90338583	Standard
# #		'HSCHR16_5_CTG3_1'	90338377	Standard
# #		'16'	90338345	Standard
# #		'HSCHR16_1_CTG3_1'	90335239	Standard
# #		'HSCHR17_1_CTG5'	83552665	Standard
# #		'HSCHR17_10_CTG4'	83359087	Standard
# #		'HSCHR17_1_CTG1'	83290495	Standard
# #		'HSCHR17_12_CTG4'	83271781	Standard
# #		'HSCHR17_3_CTG4'	83269063	Standard
# #		'HSCHR17_3_CTG1'	83267046	Standard
# #		'HSCHR17_11_CTG4'	83264946	Standard
# #		'HSCHR17_1_CTG4'	83264766	Standard
# #		'HSCHR17_9_CTG4'	83263791	Standard
# #		'HSCHR17_2_CTG4'	83263494	Standard
# #		'HG2087_PATCH'	83260478	Standard
# #		'HSCHR17_2_CTG1'	83259496	Standard
# #		'HSCHR17_8_CTG4'	83258474	Standard
# #		'HSCHR17_3_CTG2'	83258211	Standard
# #		'HSCHR17_4_CTG4'	83257896	Standard
# #		'17'	83257441	Standard
# #		'HG2046_PATCH'	83257439	Standard
# #		'HSCHR17_1_CTG2'	83256362	Standard
# #		'HSCHR17_1_CTG9'	83255504	Standard
# #		'HSCHR17_5_CTG4'	83247119	Standard
# #		'HSCHR17_6_CTG4'	83246071	Standard
# #		'HG2285_HG106_HG2252_PATCH'	83219555	Standard
# #		'HG1320_PATCH'	83207673	Standard
# #		'HSCHR17_2_CTG2'	83160220	Standard
# #		'HSCHR17_2_CTG5'	83086355	Standard
# #		'HSCHR17_7_CTG4'	83058228	Standard
# #		'HSCHR18_2_CTG2'	80442734	Standard
# #		'HSCHR18_1_CTG1'	80395815	Standard
# #		'HSCHR18_1_CTG2'	80386177	Standard
# #		'HSCHR18_1_CTG2_1'	80382671	Standard
# #		'HSCHR18_1_CTG1_1'	80380517	Standard
# #		'HSCHR18_2_CTG1_1'	80379367	Standard
# #		'HG2442_PATCH'	80379182	Standard
# #		'HSCHR18_3_CTG2_1'	80379039	Standard
# #		'HSCHR18_5_CTG1_1'	80378965	Standard
# #		'HSCHR18_2_CTG2_1'	80378720	Standard
# #		'HSCHR18_4_CTG1_1'	80378406	Standard
# #		'HG2213_PATCH'	80377536	Standard
# #		'HSCHR18_ALT2_CTG2_1'	80376883	Standard
# #		'HSCHR18_ALT21_CTG2_1'	80376343	Standard
# #		'18'	80373285	Standard
# #		'HG2412_PATCH'	80373284	Standard
# #		'HSCHR20_1_CTG1'	64450183	Standard
# #		'HSCHR20_1_CTG3'	64447812	Standard
# #		'HSCHR20_1_CTG4'	64446453	Standard
# #		'20'	64444167	Standard
# #		'HSCHR20_1_CTG2'	64441059	Standard
# #		'HSCHR19KIR_CA01-TB04_CTG3_1'	58750420	Standard
# #		'HSCHR19KIR_FH15_B_HAP_CTG3_1'	58689284	Standard
# #		'HSCHR19KIR_FH05_B_HAP_CTG3_1'	58689016	Standard
# #		'HSCHR19KIR_0019-4656-B_CTG3_1'	58675214	Standard
# #		'HSCHR19KIR_FH13_BA2_HAP_CTG3_1'	58662330	Standard
# #		'HSCHR19KIR_RSH_BA2_HAP_CTG3_1'	58662237	Standard
# #		'HSCHR19KIR_G248_BA2_HAP_CTG3_1'	58661364	Standard
# #		'HSCHR19LRC_LRC_J_CTG3_1'	58650772	Standard
# #		'HSCHR19KIR_FH08_BAX_HAP_CTG3_1'	58647709	Standard
# #		'HSCHR19KIR_CA01-TB01_CTG3_1'	58645065	Standard
# #		'HSCHR19KIR_GRC212_AB_HAP_CTG3_1'	58644315	Standard
# #		'HG2021_PATCH'	58632883	Standard
# #		'HSCHR19KIR_LUCE_BDEL_HAP_CTG3_1'	58631446	Standard
# #		'HSCHR19KIR_RP5_B_HAP_CTG3_1'	58631402	Standard
# #		'HSCHR19KIR_T7526_BDEL_HAP_CTG3_1'	58631206	Standard
# #		'HSCHR19_2_CTG2'	58627095	Standard
# #		'HSCHR19_3_CTG3_1'	58625958	Standard
# #		'HSCHR19_3_CTG2'	58625823	Standard
# #		'HSCHR19_4_CTG3_1'	58625731	Standard
# #		'HSCHR19LRC_LRC_S_CTG3_1'	58625321	Standard
# #		'HSCHR19_1_CTG3_1'	58624789	Standard
# #		'HSCHR19_1_CTG2'	58624032	Standard
# #		'HSCHR19LRC_LRC_I_CTG3_1'	58623235	Standard
# #		'HSCHR19_4_CTG2'	58619803	Standard
# #		'HSCHR19_5_CTG2'	58619095	Standard
# #		'HSCHR19_2_CTG3_1'	58618601	Standard
# #		'HSCHR19KIR_ABC08_AB_HAP_C_P_CTG3_1'	58618008	Standard
# #		'HG109_PATCH'	58617934	Standard
# #		'HSCHR19KIR_FH08_A_HAP_CTG3_1'	58617658	Standard
# #		'HG26_PATCH'	58617652	Standard
# #		'HSCHR19KIR_G248_A_HAP_CTG3_1'	58617652	Standard
# #		'HSCHR19KIR_7191059-1_CTG3_1'	58617649	Standard
# #		'HSCHR19KIR_CA01-TA01_2_CTG3_1'	58617647	Standard
# #		'HSCHR19KIR_ABC08_AB_HAP_T_P_CTG3_1'	58617636	Standard
# #		'HSCHR19KIR_LUCE_A_HAP_CTG3_1'	58617634	Standard
# #		'HSCHR19KIR_CA01-TA01_1_CTG3_1'	58617632	Standard
# #		'HSCHR19KIR_HG2394_CTG3_1'	58617630	Standard
# #		'HSCHR19KIR_ABC08_A1_HAP_CTG3_1'	58617625	Standard
# #		'19'	58617616	Standard
# #		'HSCHR19KIR_RSH_A_HAP_CTG3_1'	58617616	Standard
# #		'HSCHR19KIR_502960008-1_CTG3_1'	58617609	Standard
# #		'HSCHR19KIR_7191059-2_CTG3_1'	58617604	Standard
# #		'HSCHR19KIR_G085_A_HAP_CTG3_1'	58617601	Standard
# #		'HSCHR19KIR_T7526_A_HAP_CTG3_1'	58617601	Standard
# #		'HSCHR19KIR_FH06_A_HAP_CTG3_1'	58617587	Standard
# #		'HSCHR19KIR_FH15_A_HAP_CTG3_1'	58617473	Standard
# #		'HSCHR19KIR_0019-4656-A_CTG3_1'	58617441	Standard
# #		'HSCHR19KIR_FH05_A_HAP_CTG3_1'	58616795	Standard
# #		'HSCHR19KIR_FH13_A_HAP_CTG3_1'	58616725	Standard
# #		'HSCHR19KIR_502960008-2_CTG3_1'	58616590	Standard
# #		'HSCHR19KIR_FH06_BA1_HAP_CTG3_1'	58603994	Standard
# #		'HSCHR19KIR_HG2396_CTG3_1'	58603982	Standard
# #		'HSCHR19KIR_G085_BA1_HAP_CTG3_1'	58603800	Standard
# #		'HSCHR19KIR_GRC212_BA1_HAP_CTG3_1'	58602595	Standard
# #		'HSCHR19KIR_HG2393_CTG3_1'	58583172	Standard
# #		'HSCHR19LRC_LRC_T_CTG3_1'	58561614	Standard
# #		'HSCHR19LRC_COX1_CTG3_1'	58546647	Standard
# #		'HSCHR19LRC_PGF1_CTG3_1'	58546031	Standard
# #		'HSCHR19KIR_0010-5217-AB_CTG3_1'	58538377	Standard
# #		'HSCHR19KIR_CA04_CTG3_1'	58537114	Standard
# #		'HSCHR19LRC_PGF2_CTG3_1'	58355410	Standard
# #		'HSCHR19LRC_COX2_CTG3_1'	58288451	Standard
# #		'HG2062_PATCH'	57262172	Standard
# #		'Y'	57227415	Standard
# #		'HG1535_PATCH'	57187419	Standard
# #		'HG1531_PATCH'	57177176	Standard
# #		'HG1485_PATCH'	50915261	Standard
# #		'HSCHR22_1_CTG7'	50872732	Standard
# #		'HSCHR22_7_CTG1'	50845852	Standard
# #		'HSCHR22_1_CTG6'	50842710	Standard
# #		'HSCHR22_5_CTG1'	50832153	Standard
# #		'HSCHR22_8_CTG1'	50832130	Standard
# #		'HSCHR22_2_CTG1'	50830603	Standard
# #		'HSCHR22_1_CTG3'	50827573	Standard
# #		'HSCHR22_1_CTG4'	50824699	Standard
# #		'HSCHR22_1_CTG5'	50821308	Standard
# #		'HG1311_PATCH'	50818486	Standard
# #		'HG494_PATCH'	50818473	Standard
# #		'22'	50818468	Standard
# #		'HSCHR22_3_CTG1'	50818468	Standard
# #		'HG2512_PATCH'	50818467	Standard
# #		'HSCHR22_6_CTG1'	50815919	Standard
# #		'HSCHR22_1_CTG1'	50806372	Standard
# #		'HSCHR22_4_CTG1'	50806321	Standard
# #		'HSCHR22_1_CTG2'	50788525	Standard
# #		'HG2513_PATCH'	47068079	Standard
# #		'HSCHR21_1_CTG1_1'	46722569	Standard
# #		'HSCHR21_4_CTG1_1'	46719541	Standard
# #		'HSCHR21_2_CTG1_1'	46716685	Standard
# #		'HSCHR21_3_CTG1_1'	46715777	Standard
# #		'HSCHR21_6_CTG1_1'	46713516	Standard
# #		'HSCHR21_8_CTG1_1'	46713185	Standard
# #		'HSCHR21_5_CTG2'	46712294	Standard
# #		'21'	46709983	Standard
# #		'KI270728.1'	1872759	Standard
# #		'KI270727.1'	448248	Standard
# #		'KI270442.1'	392061	Standard
# #		'KI270729.1'	280839	Standard
# #		'GL000225.1'	211173	Standard
# #		'KI270743.1'	210658	Standard
# #		'GL000008.2'	209709	Standard
# #		'GL000009.2'	201709	Standard
# #		'KI270747.1'	198735	Standard
# #		'KI270722.1'	194050	Standard
# #		'GL000194.1'	191469	Standard
# #		'KI270742.1'	186739	Standard
# #		'GL000205.2'	185591	Standard
# #		'GL000195.1'	182896	Standard
# #		'KI270736.1'	181920	Standard
# #		'KI270733.1'	179772	Standard
# #		'GL000224.1'	179693	Standard
# #		'GL000219.1'	179198	Standard
# #		'KI270719.1'	176845	Standard
# #		'GL000216.2'	176608	Standard
# #		'KI270712.1'	176043	Standard
# #		'KI270706.1'	175055	Standard
# #		'KI270725.1'	172810	Standard
# #		'KI270744.1'	168472	Standard
# #		'KI270734.1'	165050	Standard
# #		'GL000213.1'	164239	Standard
# #		'GL000220.1'	161802	Standard
# #		'KI270715.1'	161471	Standard
# #		'GL000218.1'	161147	Standard
# #		'KI270749.1'	158759	Standard
# #		'KI270741.1'	157432	Standard
# #		'GL000221.1'	155397	Standard
# #		'KI270716.1'	153799	Standard
# #		'KI270731.1'	150754	Standard
# #		'KI270751.1'	150742	Standard
# #		'KI270750.1'	148850	Standard
# #		'KI270519.1'	138126	Standard
# #		'GL000214.1'	137718	Standard
# #		'KI270708.1'	127682	Standard
# #		'KI270730.1'	112551	Standard
# #		'KI270438.1'	112505	Standard
# #		'KI270737.1'	103838	Standard
# #		'KI270721.1'	100316	Standard
# #		'KI270738.1'	99375	Standard
# #		'KI270748.1'	93321	Standard
# #		'KI270435.1'	92983	Standard
# #		'GL000208.1'	92689	Standard
# #		'KI270538.1'	91309	Standard
# #		'KI270756.1'	79590	Standard
# #		'KI270739.1'	73985	Standard
# #		'KI270757.1'	71251	Standard
# #		'KI270709.1'	66860	Standard
# #		'KI270746.1'	66486	Standard
# #		'KI270753.1'	62944	Standard
# #		'KI270589.1'	44474	Standard
# #		'KI270726.1'	43739	Standard
# #		'KI270735.1'	42811	Standard
# #		'KI270711.1'	42210	Standard
# #		'KI270745.1'	41891	Standard
# #		'KI270714.1'	41717	Standard
# #		'KI270732.1'	41543	Standard
# #		'KI270713.1'	40745	Standard
# #		'KI270754.1'	40191	Standard
# #		'KI270710.1'	40176	Standard
# #		'KI270717.1'	40062	Standard
# #		'KI270724.1'	39555	Standard
# #		'KI270720.1'	39050	Standard
# #		'KI270723.1'	38115	Standard
# #		'KI270718.1'	38054	Standard
# #		'KI270317.1'	37690	Standard
# #		'KI270740.1'	37240	Standard
# #		'KI270755.1'	36723	Standard
# #		'KI270707.1'	32032	Standard
# #		'KI270579.1'	31033	Standard
# #		'KI270752.1'	27745	Standard
# #		'KI270512.1'	22689	Standard
# #		'KI270322.1'	21476	Standard
# #		'MT'	16569	Standard
# #		'GL000226.1'	15008	Standard
# #		'KI270311.1'	12399	Standard
# #		'KI270366.1'	8320	Standard
# #		'KI270511.1'	8127	Standard
# #		'KI270448.1'	7992	Standard
# #		'KI270521.1'	7642	Standard
# #		'KI270581.1'	7046	Standard
# #		'KI270582.1'	6504	Standard
# #		'KI270515.1'	6361	Standard
# #		'KI270588.1'	6158	Standard
# #		'KI270591.1'	5796	Standard
# #		'KI270522.1'	5674	Standard
# #		'KI270507.1'	5353	Standard
# #		'KI270590.1'	4685	Standard
# #		'KI270584.1'	4513	Standard
# #		'KI270320.1'	4416	Standard
# #		'KI270382.1'	4215	Standard
# #		'KI270468.1'	4055	Standard
# #		'KI270467.1'	3920	Standard
# #		'KI270362.1'	3530	Standard
# #		'KI270517.1'	3253	Standard
# #		'KI270593.1'	3041	Standard
# #		'KI270528.1'	2983	Standard
# #		'KI270587.1'	2969	Standard
# #		'KI270364.1'	2855	Standard
# #		'KI270371.1'	2805	Standard
# #		'KI270333.1'	2699	Standard
# #		'KI270374.1'	2656	Standard
# #		'KI270411.1'	2646	Standard
# #		'KI270414.1'	2489	Standard
# #		'KI270510.1'	2415	Standard
# #		'KI270390.1'	2387	Standard
# #		'KI270375.1'	2378	Standard
# #		'KI270420.1'	2321	Standard
# #		'KI270509.1'	2318	Standard
# #		'KI270315.1'	2276	Standard
# #		'KI270302.1'	2274	Standard
# #		'KI270518.1'	2186	Standard
# #		'KI270530.1'	2168	Standard
# #		'KI270304.1'	2165	Standard
# #		'KI270418.1'	2145	Standard
# #		'KI270424.1'	2140	Standard
# #		'KI270417.1'	2043	Standard
# #		'KI270508.1'	1951	Standard
# #		'KI270303.1'	1942	Standard
# #		'KI270381.1'	1930	Standard
# #		'KI270529.1'	1899	Standard
# #		'KI270425.1'	1884	Standard
# #		'KI270396.1'	1880	Standard
# #		'KI270363.1'	1803	Standard
# #		'KI270386.1'	1788	Standard
# #		'KI270465.1'	1774	Standard
# #		'KI270383.1'	1750	Standard
# #		'KI270384.1'	1658	Standard
# #		'KI270330.1'	1652	Standard
# #		'KI270372.1'	1650	Standard
# #		'KI270548.1'	1599	Standard
# #		'KI270580.1'	1553	Standard
# #		'KI270387.1'	1537	Standard
# #		'KI270391.1'	1484	Standard
# #		'KI270305.1'	1472	Standard
# #		'KI270373.1'	1451	Standard
# #		'KI270422.1'	1445	Standard
# #		'KI270316.1'	1444	Standard
# #		'KI270338.1'	1428	Standard
# #		'KI270340.1'	1428	Standard
# #		'KI270583.1'	1400	Standard
# #		'KI270334.1'	1368	Standard
# #		'KI270429.1'	1361	Standard
# #		'KI270393.1'	1308	Standard
# #		'KI270516.1'	1300	Standard
# #		'KI270389.1'	1298	Standard
# #		'KI270466.1'	1233	Standard
# #		'KI270388.1'	1216	Standard
# #		'KI270544.1'	1202	Standard
# #		'KI270310.1'	1201	Standard
# #		'KI270412.1'	1179	Standard
# #		'KI270395.1'	1143	Standard
# #		'KI270376.1'	1136	Standard
# #		'KI270337.1'	1121	Standard
# #		'KI270335.1'	1048	Standard
# #		'KI270378.1'	1048	Standard
# #		'KI270379.1'	1045	Standard
# #		'KI270329.1'	1040	Standard
# #		'KI270419.1'	1029	Standard
# #		'KI270336.1'	1026	Standard
# #		'KI270312.1'	998	Standard
# #		'KI270539.1'	993	Standard
# #		'KI270385.1'	990	Standard
# #		'KI270423.1'	981	Standard
# #		'KI270392.1'	971	Standard
# #		'KI270394.1'	970	Standard
# #-----------------------------------------------
#
# 00:00:23 Predicting variants
# 00:00:23 Loading sequences for chromosome '12' from file '/home/mgpersonal/miniconda3/envs/ngs/share/snpeff-5.3.0a-1/./data/GRCh38.99/sequence.12.bin'
# 00:00:24 Building sequence tree for chromosome '12'
# 00:00:24 Done. Loaded 1488 sequences.
#
# WARNINGS: Some warning were detected
# Warning type	Number of warnings
# INFO_REALIGN_3_PRIME	4
# WARNING_TRANSCRIPT_NO_STOP_CODON	3
#
#
# 00:00:25 Creating summary file: snpEff_summary.html
# 00:00:25 Creating genes file: snpEff_genes.txt
# 00:00:25 done.
# 00:00:25 Done.

# %%
# %%bash
# set -euo pipefail
# cd ~/ctdna_kras_project/results/vcf
# pwd
# ls -lh
# Out:
# /home/mgpersonal/ctdna_kras_project/results/vcf
# total 192M
# -rw-r--r-- 1 mgpersonal mgpersonal 1.2M Nov 15 15:01 C_fw075_baseline.kras.ann.vcf
# -rw-r--r-- 1 mgpersonal mgpersonal    0 Nov 14 21:42 C_fw075_baseline.kras.clinvar.tsv
# -rw-r--r-- 1 mgpersonal mgpersonal 5.7M Nov 15 15:00 C_fw075_baseline.kras.mpileup
# -rw-r--r-- 1 mgpersonal mgpersonal 460K Nov 14 22:29 C_fw075_baseline.kras.summary.tsv
# -rw-r--r-- 1 mgpersonal mgpersonal 1.2M Nov 15 15:00 C_fw075_baseline.kras.varscan.vcf
# -rw-r--r-- 1 mgpersonal mgpersonal 1.2M Nov 15 15:01 C_fw075_followup.kras.ann.vcf
# -rw-r--r-- 1 mgpersonal mgpersonal 7.2M Nov 15 15:00 C_fw075_followup.kras.mpileup
# -rw-r--r-- 1 mgpersonal mgpersonal 420K Nov 14 22:29 C_fw075_followup.kras.summary.tsv
# -rw-r--r-- 1 mgpersonal mgpersonal 1.2M Nov 15 15:00 C_fw075_followup.kras.varscan.vcf
# -rw-r--r-- 1 mgpersonal mgpersonal 173M Nov  9 14:34 clinvar.vcf.gz
# -rw-r--r-- 1 mgpersonal mgpersonal 592K Nov  9 14:34 clinvar.vcf.gz.tbi
# -rw-r--r-- 1 mgpersonal mgpersonal 1.3K Nov 15 15:01 snpEff_genes.txt
# -rw-r--r-- 1 mgpersonal mgpersonal  23K Nov 15 15:01 snpEff_summary.html

# %%
##Make parsed summary tables from the annotated .vcfs

baseline_vcf = os.path.join(vcf_dir, "C_fw075_baseline.kras.ann.vcf")
followup_vcf  = os.path.join(vcf_dir, "C_fw075_followup.kras.ann.vcf")


# Parse the SnpEff-annotated VCF and keep only KRAS variants that are missense/nonsense/splice-related and have a non-empty IMPACT field.
def extract_kras_coding(vcf_path):
 
    rows = []
    with open(vcf_path) as f:
        for line in f:
            if line.startswith("#"):
                continue

            parts = line.rstrip("\n").split("\t")
            if len(parts) < 10:
                continue

            chrom, pos, vid, ref, alt, qual, flt, info, fmt, sample = parts

            # Find ANN=... in INFO
            ann = None
            for kv in info.split(";"):
                if kv.startswith("ANN="):
                    ann = kv.split("=", 1)[1]
                    break
            if ann is None:
                continue

            # Loop over each ANN entry. We just want effect, impact, gene, cdna, and protein to represent our findins.
            for entry in ann.split(","):
                fields = entry.split("|")
                if len(fields) < 11:
                    continue

                effect  = fields[1]   
                impact  = fields[2]   
                gene    = fields[3]   
                cdna    = fields[9]   
                protein = fields[10]  

                # Only KRAS
                if gene != "KRAS":
                    continue

                # Require impact annotation
                if impact in ("", "."):
                    continue

                # Only missense / nonsense / splice-related
                effect_lower = effect.lower()
                if not (
                    "missense" in effect_lower
                    or "nonsense" in effect_lower
                    or "splice"   in effect_lower
                ):
                    continue

                # Parse FORMAT from VarScan info
                fmt_keys = fmt.split(":")
                fmt_vals = sample.split(":")
                fmt_dict = dict(zip(fmt_keys, fmt_vals))

                rd = fmt_dict.get("RD")
                ad = fmt_dict.get("AD")
                dp = fmt_dict.get("DP")
                freq = fmt_dict.get("FREQ")

                try:
                    rd_int = int(rd)
                except:
                    rd_int = np.nan

                try:
                    ad_int = int(ad)
                except:
                    ad_int = np.nan

                try:
                    dp_int = int(dp)
                except:
                    dp_int = rd_int + ad_int if not np.isnan(rd_int) else np.nan

                vaf = np.nan
                if freq and freq.endswith("%"):
                    try:
                        vaf = float(freq.rstrip("%"))
                    except:
                        vaf = np.nan

                rows.append({
                    "CHROM": chrom,
                    "POS": int(pos),
                    "REF": ref,
                    "ALT": alt,
                    "REF_COUNT": rd_int,
                    "ALT_COUNT": ad_int,
                    "DEPTH": dp_int,
                    "VAF_percent": vaf,
                    "cDNA_change": cdna,
                    "protein_change": protein,
                    "effect": effect,
                    "impact": impact,
                })

    df = pd.DataFrame(rows)

    # drop transcripts for summary
    if not df.empty:
        df = (
            df.drop_duplicates(
                subset=["CHROM", "POS", "REF", "ALT", "protein_change", "effect", "impact"]
            )
            .reset_index(drop=True)
        )

    return df

# Use the simpler extractor
baseline_kras = extract_kras_coding(baseline_vcf)
followup_kras = extract_kras_coding(followup_vcf)

print("Baseline KRAS coding/splice variants with impact:")
display(baseline_kras)

print("\nFollow-up KRAS coding/splice variants with impact:")
display(followup_kras)
# Out:
# Baseline KRAS coding/splice variants with impact:
#   CHROM       POS REF ALT  REF_COUNT  ALT_COUNT  DEPTH  VAF_percent  \
# 0    12  25245350   C   T       1201        110   1315         8.37
#
#   cDNA_change protein_change            effect    impact
# 0     c.35G>A     p.Gly12Asp  missense_variant  MODERATE
# Follow-up KRAS coding/splice variants with impact:
#   CHROM       POS REF ALT  REF_COUNT  ALT_COUNT  DEPTH  VAF_percent  \
# 0    12  25250747   G   A         44          2     46         4.35
#
#   cDNA_change protein_change                                effect impact
# 0  c.-12+4C>T                 splice_region_variant&intron_variant    LOW

# %% [markdown]
# 6. Ideas/Vision Board for visualizations for marketing or presentations
#
# With a variant calling analysis a lot of times its hard to avoid a polished summary table that shows relevant information like the Basline/follow-up tables above which ended our analysis. It is likely important for shareholders within the organization to see information like the depth and VAF, since these scientist understand all this information. For marketing to a physician or medical group it may be enough to just show the VAF. That being said, there are several figures that may communicate the table information well or support the table.
#
# 1) In my analysis I only had a single post treatment or follow-up sample, but some patients had up to 4 that I saw. A nice longitudinal plot with the x axis the dates of sample procurement and y axis being the VAF may look nice. It could communicate response of the metastatic CRC to the cetuximab over those sample time points, or if it pops up again, perhaps resistance. Either way, showing an important hotspot mutation like KRAS G12D pre or post cetuximab would likely lead to getting the patient on a type 1 KRAS inhibitor.
#
# 2) Imaging the KRAS alterations with IGV could be meaningful to internal shareholders and scientists since they understand more of the techanical and conceptual aspect of the NGS. I did not image this bam with IGV but from the depth of the KRAS G12D snp would would look striking.
#
# 3) It may be nice for internal shareholders and marketing to show a nice EGFR and downstream MAPK pathway proteins. If we need to speak specifically about KRAS we could show how normal KRAS signals and how altered KRAS signals. It certainly would be nice to see where all the panel proteins are positioned in the signaling.
